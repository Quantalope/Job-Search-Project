# %% [markdown]
# Creating the database and tables.

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",              
    password="Squ3kw!l", 
)
cur = conn.cursor()
print("Connected!")
