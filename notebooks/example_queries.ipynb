# %% [markdown]
# # Example Use Queries

# %% [markdown]
# Import libraries.

# %%
import mysql.connector
from dotenv import load_dotenv
import os
import pandas as pd

# %% [markdown]
# Load enviornment variables.

# %%
load_dotenv()

HOST = os.getenv("MYSQL_HOST", "localhost")
USER = os.getenv("MYSQL_USER", "root")
PASSWORD = os.getenv("MYSQL_PASSWORD")

# %% [markdown]
# Connect to mysql server

# %%
db = mysql.connector.connect(
    host=HOST,
    user=USER,              
    password=PASSWORD
)
cur = db.cursor()
print("Connected!")
cur.execute("USE HuskiesJob")
cur.execute("SELECT * FROM Users")
cur.fetchall()
# Out:
# Connected!
# [(1,
#   'Chris',
#   'Lewis',
#   'holly37@example.org',
#   'Data Science',
#   2025,
#   Decimal('2.72'),
#   'VA',
#   1,
#   'Customer Service',
#   'Software Development',
#   datetime.datetime(2023, 12, 31, 10, 1, 7)),
#  (2,
#   'Craig',
#   'Hicks',
#   'millsshirley@example.com',
#   'Accounting',
#   2024,
#   Decimal('2.65'),
#   'MN',
#   0,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 3, 12, 10, 47, 54)),
#  (3,
#   'Aaron',
#   'Campos',
#   'aliciawashington@example.org',
#   'Accounting',
#   2027,
#   Decimal('3.06'),
#   'MP',
#   1,
#   'Engineering',
#   'Marketing',
#   datetime.datetime(2024, 7, 12, 0, 55, 48)),
#  (4,
#   'Stephanie',
#   'Harris',
#   'cookaustin@example.net',
#   'Psychology',
#   2024,
#   Decimal('3.23'),
#   'DE',
#   1,
#   'Finance',
#   'Sales',
#   datetime.datetime(2025, 6, 18, 16, 15, 16)),
#  (5,
#   'Erik',
#   'Smith',
#   'dorseyangela@example.org',
#   'Biology',
#   2024,
#   Decimal('3.00'),
#   'GA',
#   1,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2024, 11, 28, 23, 38, 15)),
#  (6,
#   'Kyle',
#   'Mcfarland',
#   'amandahess@example.com',
#   'Accounting',
#   2025,
#   Decimal('3.16'),
#   'OK',
#   0,
#   'Software Development',
#   'Software Development',
#   datetime.datetime(2025, 2, 20, 20, 13, 53)),
#  (7,
#   'Barbara',
#   'Carrillo',
#   'jermaine51@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.84'),
#   'TN',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 10, 7, 15, 55, 44)),
#  (8,
#   'Maureen',
#   'Roberts',
#   'mcguirealbert@example.org',
#   'Biology',
#   2025,
#   Decimal('3.30'),
#   'NV',
#   0,
#   'Product Management',
#   'Product Management',
#   datetime.datetime(2024, 4, 6, 0, 9, 37)),
#  (9,
#   'Jacqueline',
#   'Davis',
#   'andersonjordan@example.net',
#   'Economics',
#   2024,
#   Decimal('3.66'),
#   'ME',
#   0,
#   'Sales',
#   'Finance',
#   datetime.datetime(2024, 3, 23, 12, 41, 12)),
#  (10,
#   'Patrick',
#   'Lee',
#   'burnswilliam@example.net',
#   'Mechanical Engineering',
#   2024,
#   Decimal('2.87'),
#   'UT',
#   0,
#   'Finance',
#   'Human Resources',
#   datetime.datetime(2024, 8, 11, 16, 58, 45)),
#  (11,
#   'Stephanie',
#   'Vasquez',
#   'christinewarren@example.net',
#   'Accounting',
#   2024,
#   Decimal('3.69'),
#   'IN',
#   1,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2024, 5, 24, 14, 19, 57)),
#  (12,
#   'Patrick',
#   'Carpenter',
#   'james82@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.80'),
#   'TX',
#   1,
#   'Supply Chain',
#   'Finance',
#   datetime.datetime(2025, 8, 30, 19, 32, 9)),
#  (13,
#   'Michael',
#   'Wood',
#   'tammyporter@example.org',
#   'Computer Science',
#   2028,
#   Decimal('2.95'),
#   'AL',
#   0,
#   'Software Development',
#   'Sales',
#   datetime.datetime(2025, 3, 6, 1, 30, 58)),
#  (14,
#   'Melissa',
#   'Jackson',
#   'kimberly63@example.com',
#   'Economics',
#   2024,
#   Decimal('3.23'),
#   'MO',
#   0,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 2, 4, 3, 30, 25)),
#  (15,
#   'Tiffany',
#   'Hamilton',
#   'kevin83@example.org',
#   'Biology',
#   2025,
#   Decimal('3.43'),
#   'WI',
#   1,
#   'Sales',
#   'Human Resources',
#   datetime.datetime(2025, 5, 21, 19, 4, 53)),
#  (16,
#   'Breanna',
#   'Webb',
#   'nicholas09@example.org',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.58'),
#   'FM',
#   1,
#   'Engineering',
#   'Marketing',
#   datetime.datetime(2023, 12, 4, 9, 6, 1)),
#  (17,
#   'Brandon',
#   'Harper',
#   'emilycannon@example.com',
#   'Economics',
#   2026,
#   Decimal('3.47'),
#   'IN',
#   1,
#   'Product Management',
#   'Sales',
#   datetime.datetime(2024, 2, 28, 8, 14, 42)),
#  (18,
#   'Ricardo',
#   'Lee',
#   'jerryramos@example.com',
#   'Computer Science',
#   2027,
#   Decimal('2.54'),
#   'TX',
#   1,
#   'Product Management',
#   'Marketing',
#   datetime.datetime(2025, 11, 2, 19, 13, 37)),
#  (19,
#   'Anthony',
#   'Marshall',
#   'allen12@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.88'),
#   'CO',
#   0,
#   'Human Resources',
#   'Data Analysis',
#   datetime.datetime(2025, 6, 18, 5, 14, 16)),
#  (20,
#   'Nicole',
#   'Shaw',
#   'karen14@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.75'),
#   'HI',
#   0,
#   'Finance',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 29, 15, 44, 58)),
#  (21,
#   'Wesley',
#   'Jones',
#   'stephaniesmith@example.org',
#   'Accounting',
#   2028,
#   Decimal('3.97'),
#   'IA',
#   1,
#   'Marketing',
#   'Research',
#   datetime.datetime(2024, 8, 4, 19, 43, 28)),
#  (22,
#   'Michael',
#   'Lucas',
#   'jacob09@example.net',
#   'Economics',
#   2026,
#   Decimal('3.22'),
#   'MN',
#   0,
#   'Human Resources',
#   'Data Analysis',
#   datetime.datetime(2023, 12, 10, 9, 14, 5)),
#  (23,
#   'Andrew',
#   'Dixon',
#   'danielmaldonado@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.95'),
#   'PW',
#   1,
#   'Software Development',
#   'Software Development',
#   datetime.datetime(2024, 5, 25, 6, 31, 59)),
#  (24,
#   'Nicholas',
#   'Kennedy',
#   'sethpadilla@example.org',
#   'Economics',
#   2025,
#   Decimal('3.51'),
#   'ME',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 2, 7, 23, 24, 16)),
#  (25,
#   'Diane',
#   'Sherman',
#   'morrissylvia@example.com',
#   'Data Science',
#   2027,
#   Decimal('2.98'),
#   'SD',
#   1,
#   'Sales',
#   'Product Management',
#   datetime.datetime(2024, 3, 30, 4, 39, 59)),
#  (26,
#   'Meagan',
#   'Lewis',
#   'amanda10@example.net',
#   'Biology',
#   2024,
#   Decimal('3.18'),
#   'MN',
#   1,
#   'Software Development',
#   'Customer Service',
#   datetime.datetime(2025, 7, 13, 5, 32, 54)),
#  (27,
#   'Kimberly',
#   'Taylor',
#   'kenneth30@example.net',
#   'Finance',
#   2024,
#   Decimal('3.32'),
#   'NV',
#   1,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2024, 3, 29, 7, 15, 47)),
#  (28,
#   'Edward',
#   'Hartman',
#   'nsanchez@example.org',
#   'Accounting',
#   2024,
#   Decimal('3.25'),
#   'AS',
#   0,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 9, 2, 2, 57, 41)),
#  (29,
#   'Cathy',
#   'Bradley',
#   'campbelldavid@example.com',
#   'Finance',
#   2028,
#   Decimal('2.77'),
#   'NC',
#   1,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 10, 24, 5, 41, 38)),
#  (30,
#   'Tracy',
#   'Kennedy',
#   'elliottlindsey@example.com',
#   'Data Science',
#   2025,
#   Decimal('3.93'),
#   'KS',
#   1,
#   'Software Development',
#   'Sales',
#   datetime.datetime(2025, 9, 29, 23, 23, 59)),
#  (31,
#   'Jennifer',
#   'Leach',
#   'rebeccabailey@example.org',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.57'),
#   'MH',
#   0,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 8, 27, 14, 39, 3)),
#  (32,
#   'Nicolas',
#   'Gonzalez',
#   'sotocarolyn@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.54'),
#   'MN',
#   1,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 2, 19, 22, 50, 30)),
#  (33,
#   'Betty',
#   'Rosales',
#   'joshua39@example.com',
#   'Psychology',
#   2024,
#   Decimal('3.63'),
#   'LA',
#   1,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2024, 10, 21, 19, 12, 26)),
#  (34,
#   'Elizabeth',
#   'Garrett',
#   'swiggins@example.org',
#   'Information Systems',
#   2025,
#   Decimal('3.07'),
#   'CO',
#   0,
#   'Software Development',
#   'Supply Chain',
#   datetime.datetime(2025, 2, 2, 0, 44, 44)),
#  (35,
#   'Christina',
#   'Bailey',
#   'sgonzalez@example.org',
#   'Information Systems',
#   2028,
#   Decimal('3.83'),
#   'DE',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2025, 4, 1, 12, 26, 26)),
#  (36,
#   'Joy',
#   'Oneal',
#   'richardcannon@example.org',
#   'Marketing',
#   2025,
#   Decimal('2.96'),
#   'VA',
#   0,
#   'Sales',
#   'Software Development',
#   datetime.datetime(2024, 4, 4, 10, 42, 45)),
#  (37,
#   'Marissa',
#   'Hawkins',
#   'gregoryortiz@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.94'),
#   'ND',
#   0,
#   'Supply Chain',
#   'Marketing',
#   datetime.datetime(2024, 9, 25, 13, 47, 42)),
#  (38,
#   'Veronica',
#   'Lopez',
#   'scottgrant@example.org',
#   'Economics',
#   2025,
#   Decimal('3.21'),
#   'DE',
#   1,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 8, 21, 3, 22, 16)),
#  (39,
#   'Mary',
#   'Dennis',
#   'matthew82@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.71'),
#   'NM',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 3, 17, 17, 28, 16)),
#  (40,
#   'Sheryl',
#   'Patterson',
#   'howardrobert@example.org',
#   'Accounting',
#   2025,
#   Decimal('2.50'),
#   'IN',
#   0,
#   'Marketing',
#   'Marketing',
#   datetime.datetime(2024, 3, 20, 2, 57, 46)),
#  (41,
#   'Steven',
#   'Santiago',
#   'mmartinez@example.com',
#   'Computer Science',
#   2025,
#   Decimal('3.13'),
#   'NH',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2025, 7, 31, 2, 39, 51)),
#  (42,
#   'Jason',
#   'Allen',
#   'hallanna@example.org',
#   'Economics',
#   2028,
#   Decimal('3.65'),
#   'PW',
#   0,
#   'Marketing',
#   'Finance',
#   datetime.datetime(2025, 1, 6, 13, 47, 36)),
#  (43,
#   'Steven',
#   'Miller',
#   'christophermata@example.com',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.84'),
#   'MT',
#   0,
#   'Customer Service',
#   'Product Management',
#   datetime.datetime(2025, 8, 12, 19, 13, 34)),
#  (44,
#   'Craig',
#   'Simmons',
#   'calebbeck@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.84'),
#   'UT',
#   0,
#   'Human Resources',
#   'Finance',
#   datetime.datetime(2024, 9, 23, 11, 35, 45)),
#  (45,
#   'Shannon',
#   'Wall',
#   'herringstephanie@example.com',
#   'Accounting',
#   2025,
#   Decimal('3.86'),
#   'GA',
#   0,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 7, 15, 3, 31, 54)),
#  (46,
#   'Claire',
#   'Bryant',
#   'rcole@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.40'),
#   'PR',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 2, 3, 8, 43, 36)),
#  (47,
#   'Kenneth',
#   'Mcdaniel',
#   'porterchristopher@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.36'),
#   'IL',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2025, 4, 1, 13, 2, 41)),
#  (48,
#   'Bradley',
#   'Williams',
#   'chris10@example.org',
#   'Finance',
#   2026,
#   Decimal('2.61'),
#   'ID',
#   0,
#   'Finance',
#   'Human Resources',
#   datetime.datetime(2024, 12, 8, 3, 41, 5)),
#  (49,
#   'Charles',
#   'Nelson',
#   'jacobspaul@example.org',
#   'Information Systems',
#   2024,
#   Decimal('3.44'),
#   'NY',
#   0,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 4, 7, 6, 55, 38)),
#  (50,
#   'Shannon',
#   'Mayer',
#   'esparzalinda@example.com',
#   'Computer Science',
#   2024,
#   Decimal('3.33'),
#   'ME',
#   1,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2025, 6, 4, 14, 22, 23)),
#  (51,
#   'Allen',
#   'Evans',
#   'jamesalexander@example.com',
#   'Marketing',
#   2025,
#   Decimal('2.68'),
#   'TX',
#   1,
#   'Engineering',
#   'Research',
#   datetime.datetime(2025, 11, 28, 19, 35, 5)),
#  (52,
#   'Scott',
#   'Ryan',
#   'dominique90@example.org',
#   'Business Administration',
#   2027,
#   Decimal('3.69'),
#   'FL',
#   1,
#   'Research',
#   'Marketing',
#   datetime.datetime(2024, 4, 22, 14, 26, 30)),
#  (53,
#   'April',
#   'Morrison',
#   'jayhernandez@example.net',
#   'Psychology',
#   2028,
#   Decimal('3.56'),
#   'AL',
#   1,
#   'Marketing',
#   'Human Resources',
#   datetime.datetime(2025, 8, 20, 15, 45, 24)),
#  (54,
#   'Rhonda',
#   'Miller',
#   'meganmiller@example.org',
#   'Biology',
#   2028,
#   Decimal('3.32'),
#   'NV',
#   1,
#   'Marketing',
#   'Finance',
#   datetime.datetime(2025, 4, 5, 2, 40, 57)),
#  (55,
#   'Kevin',
#   'Wolf',
#   'taylor26@example.org',
#   'Information Systems',
#   2025,
#   Decimal('3.16'),
#   'AL',
#   1,
#   'Data Analysis',
#   'Marketing',
#   datetime.datetime(2024, 8, 19, 17, 42, 20)),
#  (56,
#   'Christine',
#   'Herrera',
#   'scombs@example.net',
#   'Accounting',
#   2026,
#   Decimal('3.00'),
#   'WI',
#   1,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 12, 9, 7, 24, 49)),
#  (57,
#   'Stacy',
#   'Perez',
#   'kelsey70@example.com',
#   'Business Administration',
#   2028,
#   Decimal('3.14'),
#   'WY',
#   1,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2025, 10, 24, 13, 58, 24)),
#  (58,
#   'John',
#   'Henderson',
#   'bradleyvaughn@example.org',
#   'Accounting',
#   2024,
#   Decimal('2.83'),
#   'NH',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 3, 4, 0, 57, 40)),
#  (59,
#   'Daniel',
#   'Phillips',
#   'acaldwell@example.net',
#   'Biology',
#   2024,
#   Decimal('3.34'),
#   'CA',
#   0,
#   'Customer Service',
#   'Sales',
#   datetime.datetime(2023, 12, 7, 3, 57, 52)),
#  (60,
#   'Angelica',
#   'Stein',
#   'zgrant@example.net',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.88'),
#   'MS',
#   1,
#   'Sales',
#   'Human Resources',
#   datetime.datetime(2024, 12, 1, 23, 14, 34)),
#  (61,
#   'Gregory',
#   'Salazar',
#   'elainemassey@example.com',
#   'Psychology',
#   2026,
#   Decimal('2.63'),
#   'NY',
#   0,
#   'Research',
#   'Data Analysis',
#   datetime.datetime(2025, 3, 30, 11, 40, 33)),
#  (62,
#   'Greg',
#   'Robinson',
#   'santosrachel@example.net',
#   'Biology',
#   2025,
#   Decimal('2.64'),
#   'IL',
#   0,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2024, 7, 9, 19, 37, 51)),
#  (63,
#   'Julie',
#   'Evans',
#   'robin29@example.org',
#   'Data Science',
#   2027,
#   Decimal('3.95'),
#   'UT',
#   1,
#   'Data Analysis',
#   'Customer Service',
#   datetime.datetime(2024, 4, 13, 21, 30, 24)),
#  (64,
#   'Kelsey',
#   'Frey',
#   'emilyhudson@example.org',
#   'Information Systems',
#   2024,
#   Decimal('3.55'),
#   'AZ',
#   0,
#   'Human Resources',
#   'Software Development',
#   datetime.datetime(2024, 9, 28, 13, 56, 9)),
#  (65,
#   'Patricia',
#   'Padilla',
#   'stacy84@example.net',
#   'Marketing',
#   2026,
#   Decimal('3.91'),
#   'MS',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 8, 6, 21, 54, 42)),
#  (66,
#   'Tony',
#   'Jacobs',
#   'stephen87@example.net',
#   'Biology',
#   2027,
#   Decimal('3.55'),
#   'WA',
#   0,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2023, 12, 12, 7, 55, 48)),
#  (67,
#   'Dennis',
#   'Riley',
#   'masonangela@example.net',
#   'Finance',
#   2024,
#   Decimal('3.53'),
#   'NE',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 6, 7, 4, 25, 44)),
#  (68,
#   'Mark',
#   'Davis',
#   'anna74@example.net',
#   'Data Science',
#   2027,
#   Decimal('2.81'),
#   'TX',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2024, 9, 4, 9, 21, 37)),
#  (69,
#   'Alexa',
#   'Rogers',
#   'maryclark@example.com',
#   'Finance',
#   2024,
#   Decimal('3.17'),
#   'PR',
#   1,
#   'Software Development',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 11, 4, 35, 4)),
#  (70,
#   'Rebecca',
#   'Trujillo',
#   'eric07@example.com',
#   'Information Systems',
#   2024,
#   Decimal('2.79'),
#   'DE',
#   0,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2025, 7, 18, 2, 38, 25)),
#  (71,
#   'Erica',
#   'Mcneil',
#   'laurenking@example.org',
#   'Finance',
#   2024,
#   Decimal('3.41'),
#   'NH',
#   0,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 6, 1, 14, 46, 49)),
#  (72,
#   'John',
#   'Wright',
#   'michael05@example.net',
#   'Psychology',
#   2027,
#   Decimal('3.05'),
#   'MT',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2025, 4, 3, 18, 52, 13)),
#  (73,
#   'Hannah',
#   'Horn',
#   'banksmary@example.net',
#   'Biology',
#   2026,
#   Decimal('3.56'),
#   'IL',
#   0,
#   'Finance',
#   'Operations',
#   datetime.datetime(2025, 1, 24, 14, 6, 1)),
#  (74,
#   'Henry',
#   'Turner',
#   'garywarner@example.com',
#   'Marketing',
#   2025,
#   Decimal('3.64'),
#   'NE',
#   0,
#   'Human Resources',
#   'Supply Chain',
#   datetime.datetime(2024, 1, 16, 12, 50, 55)),
#  (75,
#   'Christina',
#   'Velazquez',
#   'qsteele@example.net',
#   'Biology',
#   2025,
#   Decimal('3.31'),
#   'VA',
#   0,
#   'Supply Chain',
#   'Supply Chain',
#   datetime.datetime(2024, 11, 10, 2, 5, 31)),
#  (76,
#   'Jake',
#   'Mccarty',
#   'malonevalerie@example.net',
#   'Economics',
#   2024,
#   Decimal('2.61'),
#   'IL',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2025, 6, 25, 11, 10, 8)),
#  (77,
#   'John',
#   'Williams',
#   'peter93@example.com',
#   'Computer Science',
#   2025,
#   Decimal('2.83'),
#   'WY',
#   1,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2025, 7, 14, 3, 36, 53)),
#  (78,
#   'Alexandra',
#   'Howard',
#   'michele10@example.com',
#   'Computer Science',
#   2028,
#   Decimal('2.63'),
#   'MT',
#   1,
#   'Marketing',
#   'Data Analysis',
#   datetime.datetime(2024, 10, 6, 16, 47, 19)),
#  (79,
#   'Andrew',
#   'Larson',
#   'brennancrystal@example.org',
#   'Business Administration',
#   2024,
#   Decimal('3.16'),
#   'VT',
#   0,
#   'Research',
#   'Software Development',
#   datetime.datetime(2025, 5, 8, 16, 17, 12)),
#  (80,
#   'Jeffrey',
#   'Johnson',
#   'djordan@example.org',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.43'),
#   'NC',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 10, 8, 12, 46, 30)),
#  (81,
#   'Lisa',
#   'Wheeler',
#   'james35@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.43'),
#   'LA',
#   0,
#   'Human Resources',
#   'Product Management',
#   datetime.datetime(2025, 8, 10, 21, 26, 21)),
#  (82,
#   'Marcus',
#   'Espinoza',
#   'davidpugh@example.org',
#   'Finance',
#   2028,
#   Decimal('3.66'),
#   'SC',
#   1,
#   'Engineering',
#   'Operations',
#   datetime.datetime(2025, 6, 6, 5, 32, 51)),
#  (83,
#   'Rodney',
#   'Fernandez',
#   'terrycorey@example.com',
#   'Computer Science',
#   2027,
#   Decimal('2.53'),
#   'WV',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 3, 25, 9, 30, 52)),
#  (84,
#   'Joshua',
#   'Perry',
#   'cindy96@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.53'),
#   'KS',
#   1,
#   'Customer Service',
#   'Data Analysis',
#   datetime.datetime(2024, 2, 5, 6, 6, 55)),
#  (85,
#   'Amy',
#   'Mills',
#   'hollyhayes@example.com',
#   'Data Science',
#   2026,
#   Decimal('2.94'),
#   'ND',
#   0,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2024, 12, 20, 8, 55, 31)),
#  (86,
#   'Jennifer',
#   'Taylor',
#   'delgadokimberly@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.94'),
#   'AR',
#   1,
#   'Engineering',
#   'Customer Service',
#   datetime.datetime(2025, 11, 11, 19, 21, 10)),
#  (87,
#   'Ruben',
#   'Kelly',
#   'wardleonard@example.net',
#   'Accounting',
#   2027,
#   Decimal('3.34'),
#   'CT',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 9, 17, 22, 47, 7)),
#  (88,
#   'Jorge',
#   'Thompson',
#   'egreene@example.com',
#   'Data Science',
#   2028,
#   Decimal('3.16'),
#   'HI',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 6, 9, 15, 44)),
#  (89,
#   'David',
#   'Baldwin',
#   'william08@example.net',
#   'Economics',
#   2025,
#   Decimal('2.57'),
#   'MA',
#   0,
#   'Research',
#   'Software Development',
#   datetime.datetime(2024, 6, 2, 16, 50)),
#  (90,
#   'James',
#   'Russell',
#   'yatesnicole@example.org',
#   'Information Systems',
#   2025,
#   Decimal('2.93'),
#   'MA',
#   0,
#   'Finance',
#   'Supply Chain',
#   datetime.datetime(2024, 1, 10, 17, 4, 51)),
#  (91,
#   'Valerie',
#   'Barrett',
#   'marcusvazquez@example.net',
#   'Business Administration',
#   2028,
#   Decimal('2.87'),
#   'NC',
#   1,
#   'Research',
#   'Engineering',
#   datetime.datetime(2024, 4, 13, 12, 36, 26)),
#  (92,
#   'Brandy',
#   'Wolfe',
#   'rowedarrell@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.36'),
#   'FL',
#   1,
#   'Software Development',
#   'Human Resources',
#   datetime.datetime(2025, 5, 16, 5, 54, 14)),
#  (93,
#   'Christopher',
#   'Miller',
#   'brentlawson@example.org',
#   'Marketing',
#   2024,
#   Decimal('3.84'),
#   'DE',
#   0,
#   'Engineering',
#   'Human Resources',
#   datetime.datetime(2024, 3, 28, 0, 24, 5)),
#  (94,
#   'Larry',
#   'Ramos',
#   'briggssteven@example.net',
#   'Biology',
#   2028,
#   Decimal('2.94'),
#   'KS',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 9, 17, 20, 4, 16)),
#  (95,
#   'Kaitlyn',
#   'Marshall',
#   'pvelazquez@example.net',
#   'Psychology',
#   2027,
#   Decimal('3.61'),
#   'WY',
#   1,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 3, 17, 10, 34, 17)),
#  (96,
#   'Elizabeth',
#   'Oconnor',
#   'alyssa24@example.com',
#   'Information Systems',
#   2024,
#   Decimal('3.25'),
#   'TX',
#   0,
#   'Sales',
#   'Operations',
#   datetime.datetime(2025, 6, 9, 19, 57, 9)),
#  (97,
#   'Jacob',
#   'Cantu',
#   'zsmith@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('3.53'),
#   'RI',
#   1,
#   'Customer Service',
#   'Finance',
#   datetime.datetime(2024, 5, 4, 3, 52, 59)),
#  (98,
#   'John',
#   'Moore',
#   'rebecca23@example.org',
#   'Information Systems',
#   2026,
#   Decimal('3.28'),
#   'NC',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 7, 27, 2, 38, 22)),
#  (99,
#   'Austin',
#   'Ortiz',
#   'larsondeborah@example.org',
#   'Electrical Engineering',
#   2025,
#   Decimal('3.79'),
#   'DC',
#   0,
#   'Sales',
#   'Research',
#   datetime.datetime(2024, 8, 17, 4, 17, 34)),
#  (100,
#   'Karen',
#   'Patterson',
#   'nrandolph@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.73'),
#   'SC',
#   1,
#   'Customer Service',
#   'Customer Service',
#   datetime.datetime(2024, 11, 10, 6, 7, 7)),
#  (101,
#   'Darrell',
#   'Collins',
#   'daniellescott@example.org',
#   'Data Science',
#   2028,
#   Decimal('2.72'),
#   'AZ',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 8, 26, 9, 47, 42)),
#  (102,
#   'Randy',
#   'Koch',
#   'clarktommy@example.net',
#   'Marketing',
#   2027,
#   Decimal('3.56'),
#   'KS',
#   0,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 9, 26, 17, 49, 11)),
#  (103,
#   'Amanda',
#   'Bruce',
#   'ginalopez@example.com',
#   'Finance',
#   2026,
#   Decimal('3.46'),
#   'ID',
#   1,
#   'Supply Chain',
#   'Research',
#   datetime.datetime(2024, 6, 9, 23, 27, 10)),
#  (104,
#   'Melissa',
#   'Castro',
#   'goldenalexis@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.44'),
#   'DC',
#   1,
#   'Data Analysis',
#   'Supply Chain',
#   datetime.datetime(2023, 12, 11, 3, 2, 22)),
#  (105,
#   'Susan',
#   'Chase',
#   'matthew34@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.59'),
#   'AS',
#   1,
#   'Finance',
#   'Software Development',
#   datetime.datetime(2024, 7, 13, 20, 11, 40)),
#  (106,
#   'William',
#   'Lambert',
#   'ycook@example.net',
#   'Business Administration',
#   2025,
#   Decimal('2.56'),
#   'IA',
#   0,
#   'Customer Service',
#   'Human Resources',
#   datetime.datetime(2024, 9, 8, 15, 28, 9)),
#  (107,
#   'Michael',
#   'Miller',
#   'kennethjohnson@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.15'),
#   'TX',
#   0,
#   'Customer Service',
#   'Research',
#   datetime.datetime(2025, 8, 24, 22, 8, 59)),
#  (108,
#   'Samantha',
#   'West',
#   'davisjennifer@example.net',
#   'Finance',
#   2028,
#   Decimal('3.60'),
#   'PA',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2024, 3, 9, 23, 6, 6)),
#  (109,
#   'Justin',
#   'West',
#   'ambermontes@example.org',
#   'Accounting',
#   2025,
#   Decimal('3.60'),
#   'GU',
#   1,
#   'Supply Chain',
#   'Supply Chain',
#   datetime.datetime(2024, 6, 5, 19, 2, 59)),
#  (110,
#   'Andrea',
#   'Hogan',
#   'michele35@example.com',
#   'Psychology',
#   2026,
#   Decimal('3.09'),
#   'ME',
#   1,
#   'Customer Service',
#   'Engineering',
#   datetime.datetime(2025, 10, 14, 18, 54, 18)),
#  (111,
#   'Christine',
#   'Austin',
#   'joediaz@example.com',
#   'Marketing',
#   2026,
#   Decimal('2.69'),
#   'MI',
#   0,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 1, 5, 19, 51, 16)),
#  (112,
#   'Kathy',
#   'Campbell',
#   'melinda71@example.com',
#   'Computer Science',
#   2027,
#   Decimal('3.11'),
#   'GA',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 11, 12, 3, 26, 13)),
#  (113,
#   'Nicole',
#   'York',
#   'thomassmith@example.net',
#   'Data Science',
#   2024,
#   Decimal('3.81'),
#   'KY',
#   1,
#   'Research',
#   'Supply Chain',
#   datetime.datetime(2024, 5, 19, 8, 34, 13)),
#  (114,
#   'Anne',
#   'Baldwin',
#   'xmiller@example.net',
#   'Marketing',
#   2024,
#   Decimal('2.54'),
#   'RI',
#   0,
#   'Human Resources',
#   'Software Development',
#   datetime.datetime(2024, 1, 30, 4, 9, 58)),
#  (115,
#   'Aaron',
#   'Stark',
#   'brittanyflores@example.com',
#   'Computer Science',
#   2028,
#   Decimal('3.81'),
#   'VI',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2025, 8, 3, 6, 17, 34)),
#  (116,
#   'Tammy',
#   'Mcgee',
#   'curtisramirez@example.com',
#   'Finance',
#   2025,
#   Decimal('3.27'),
#   'NM',
#   0,
#   'Software Development',
#   'Finance',
#   datetime.datetime(2024, 4, 1, 22, 38, 9)),
#  (117,
#   'Mary',
#   'Obrien',
#   'emilyshelton@example.com',
#   'Mechanical Engineering',
#   2025,
#   Decimal('3.57'),
#   'GA',
#   1,
#   'Data Analysis',
#   'Marketing',
#   datetime.datetime(2024, 5, 29, 14, 11, 54)),
#  (118,
#   'Joseph',
#   'Riggs',
#   'sara07@example.org',
#   'Economics',
#   2025,
#   Decimal('3.46'),
#   'CO',
#   0,
#   'Operations',
#   'Engineering',
#   datetime.datetime(2024, 3, 5, 0, 15, 36)),
#  (119,
#   'Parker',
#   'Warren',
#   'charles37@example.net',
#   'Economics',
#   2024,
#   Decimal('3.55'),
#   'NV',
#   1,
#   'Sales',
#   'Operations',
#   datetime.datetime(2025, 8, 7, 17, 10, 45)),
#  (120,
#   'Sonya',
#   'Lopez',
#   'adamsosa@example.org',
#   'Business Administration',
#   2026,
#   Decimal('2.83'),
#   'AS',
#   0,
#   'Product Management',
#   'Human Resources',
#   datetime.datetime(2024, 1, 25, 16, 21, 7)),
#  (121,
#   'Aaron',
#   'Roberson',
#   'anthonyjennings@example.com',
#   'Economics',
#   2027,
#   Decimal('3.98'),
#   'NM',
#   0,
#   'Data Analysis',
#   'Engineering',
#   datetime.datetime(2024, 12, 6, 11, 25, 20)),
#  (122,
#   'Tammy',
#   'Vaughn',
#   'danagray@example.com',
#   'Psychology',
#   2028,
#   Decimal('2.83'),
#   'OH',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2024, 6, 23, 4, 50, 12)),
#  (123,
#   'John',
#   'Forbes',
#   'trevinocindy@example.com',
#   'Biology',
#   2025,
#   Decimal('2.80'),
#   'DE',
#   1,
#   'Human Resources',
#   'Engineering',
#   datetime.datetime(2024, 5, 13, 6, 41, 14)),
#  (124,
#   'Brittany',
#   'Anderson',
#   'huntashley@example.org',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.56'),
#   'GA',
#   1,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 6, 15, 11, 37, 23)),
#  (125,
#   'Angela',
#   'Farmer',
#   'ryan06@example.org',
#   'Psychology',
#   2024,
#   Decimal('3.06'),
#   'NM',
#   1,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2024, 8, 12, 15, 37, 57)),
#  (126,
#   'Garrett',
#   'Pace',
#   'tnavarro@example.org',
#   'Economics',
#   2026,
#   Decimal('2.61'),
#   'KY',
#   1,
#   'Research',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 20, 16, 46, 40)),
#  (127,
#   'Brittany',
#   'Todd',
#   'smithjulia@example.com',
#   'Mechanical Engineering',
#   2028,
#   Decimal('3.04'),
#   'MT',
#   1,
#   'Engineering',
#   'Supply Chain',
#   datetime.datetime(2025, 7, 24, 4, 6, 49)),
#  (128,
#   'Jeffrey',
#   'Cantrell',
#   'mmarshall@example.com',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.80'),
#   'MA',
#   0,
#   'Customer Service',
#   'Software Development',
#   datetime.datetime(2024, 8, 15, 8, 18, 53)),
#  (129,
#   'Christine',
#   'Clay',
#   'ztaylor@example.org',
#   'Mechanical Engineering',
#   2024,
#   Decimal('3.01'),
#   'AL',
#   0,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 2, 10, 11, 36, 34)),
#  (130,
#   'Sandra',
#   'Sanchez',
#   'hedwards@example.net',
#   'Marketing',
#   2026,
#   Decimal('2.83'),
#   'KS',
#   0,
#   'Engineering',
#   'Engineering',
#   datetime.datetime(2025, 5, 31, 23, 0, 28)),
#  (131,
#   'Donna',
#   'Jackson',
#   'nicole47@example.net',
#   'Business Administration',
#   2028,
#   Decimal('3.91'),
#   'NC',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2024, 12, 4, 15, 7)),
#  (132,
#   'Michael',
#   'Wilson',
#   'chris61@example.org',
#   'Computer Science',
#   2024,
#   Decimal('3.42'),
#   'MO',
#   1,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 10, 10, 13, 34, 55)),
#  (133,
#   'Jason',
#   'Hanson',
#   'sherrycollins@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('2.66'),
#   'MO',
#   1,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 3, 15, 19, 8, 2)),
#  (134,
#   'James',
#   'Moore',
#   'ryanquinn@example.org',
#   'Finance',
#   2025,
#   Decimal('2.68'),
#   'TN',
#   0,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2023, 12, 8, 15, 54, 56)),
#  (135,
#   'Robert',
#   'Poole',
#   'qhunter@example.org',
#   'Psychology',
#   2024,
#   Decimal('3.72'),
#   'CT',
#   0,
#   'Finance',
#   'Supply Chain',
#   datetime.datetime(2025, 6, 4, 14, 54, 3)),
#  (136,
#   'Jerry',
#   'Griffin',
#   'morgananthony@example.org',
#   'Finance',
#   2027,
#   Decimal('3.62'),
#   'SD',
#   0,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2025, 7, 13, 7, 9, 54)),
#  (137,
#   'Brent',
#   'Johnson',
#   'jefferyroberts@example.org',
#   'Mechanical Engineering',
#   2025,
#   Decimal('3.96'),
#   'WA',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2025, 11, 3, 6, 51, 43)),
#  (138,
#   'Michele',
#   'Hines',
#   'garciakathy@example.net',
#   'Accounting',
#   2026,
#   Decimal('3.29'),
#   'VA',
#   1,
#   'Finance',
#   'Finance',
#   datetime.datetime(2024, 4, 27, 3, 3, 34)),
#  (139,
#   'Tara',
#   'Ruiz',
#   'zmeyer@example.net',
#   'Information Systems',
#   2025,
#   Decimal('3.42'),
#   'GU',
#   1,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2025, 9, 11, 8, 54, 6)),
#  (140,
#   'Brian',
#   'Wallace',
#   'perezmichael@example.net',
#   'Computer Science',
#   2024,
#   Decimal('3.11'),
#   'NE',
#   1,
#   'Sales',
#   'Customer Service',
#   datetime.datetime(2024, 6, 21, 12, 44, 39)),
#  (141,
#   'Matthew',
#   'Ballard',
#   'cobbanthony@example.net',
#   'Business Administration',
#   2028,
#   Decimal('2.91'),
#   'MA',
#   1,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 8, 25, 21, 50, 40)),
#  (142,
#   'Elizabeth',
#   'Mcdonald',
#   'lorihoward@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.55'),
#   'FL',
#   0,
#   'Software Development',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 19, 11, 19, 49)),
#  (143,
#   'Jodi',
#   'Goodman',
#   'amybrooks@example.net',
#   'Economics',
#   2026,
#   Decimal('3.47'),
#   'MO',
#   1,
#   'Marketing',
#   'Operations',
#   datetime.datetime(2025, 7, 23, 3, 35, 45)),
#  (144,
#   'Kelsey',
#   'Galloway',
#   'lanejohn@example.net',
#   'Finance',
#   2027,
#   Decimal('2.99'),
#   'GU',
#   0,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2024, 2, 20, 16, 17, 43)),
#  (145,
#   'Michelle',
#   'Powers',
#   'campbellandrea@example.org',
#   'Computer Science',
#   2027,
#   Decimal('2.67'),
#   'OR',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 11, 8, 8, 33, 14)),
#  (146,
#   'Thomas',
#   'Barr',
#   'jgarcia@example.com',
#   'Information Systems',
#   2025,
#   Decimal('2.89'),
#   'OH',
#   1,
#   'Software Development',
#   'Human Resources',
#   datetime.datetime(2025, 2, 28, 14, 36, 19)),
#  (147,
#   'Hunter',
#   'Garza',
#   'gdiaz@example.com',
#   'Information Systems',
#   2024,
#   Decimal('2.81'),
#   'CO',
#   0,
#   'Research',
#   'Finance',
#   datetime.datetime(2025, 9, 21, 7, 55, 14)),
#  (148,
#   'Melissa',
#   'Jefferson',
#   'diana43@example.com',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.08'),
#   'WA',
#   1,
#   'Supply Chain',
#   'Marketing',
#   datetime.datetime(2025, 4, 6, 18, 2, 3)),
#  (149,
#   'Richard',
#   'Williams',
#   'imendez@example.org',
#   'Data Science',
#   2026,
#   Decimal('2.79'),
#   'WV',
#   0,
#   'Engineering',
#   'Customer Service',
#   datetime.datetime(2025, 2, 2, 10, 23, 6)),
#  (150,
#   'Brandon',
#   'Fernandez',
#   'qtaylor@example.com',
#   'Psychology',
#   2024,
#   Decimal('3.81'),
#   'KS',
#   1,
#   'Research',
#   'Customer Service',
#   datetime.datetime(2024, 2, 10, 4, 0, 15)),
#  (151,
#   'James',
#   'Parrish',
#   'brianturner@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.94'),
#   'MD',
#   0,
#   'Operations',
#   'Marketing',
#   datetime.datetime(2024, 3, 14, 22, 26, 3)),
#  (152,
#   'Jessica',
#   'Mcclure',
#   'derek14@example.com',
#   'Marketing',
#   2026,
#   Decimal('3.81'),
#   'RI',
#   0,
#   'Engineering',
#   'Supply Chain',
#   datetime.datetime(2024, 8, 7, 17, 7, 57)),
#  (153,
#   'Stacey',
#   'Burgess',
#   'omoss@example.com',
#   'Information Systems',
#   2028,
#   Decimal('3.23'),
#   'WA',
#   0,
#   'Supply Chain',
#   'Sales',
#   datetime.datetime(2025, 4, 20, 2, 0, 10)),
#  (154,
#   'Carrie',
#   'Rivas',
#   'pruittbrian@example.org',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.79'),
#   'KY',
#   1,
#   'Sales',
#   'Finance',
#   datetime.datetime(2024, 4, 12, 3, 51, 49)),
#  (155,
#   'Jason',
#   'Petty',
#   'melanie57@example.org',
#   'Accounting',
#   2024,
#   Decimal('3.06'),
#   'SC',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 6, 2, 21, 20, 52)),
#  (156,
#   'Mark',
#   'Torres',
#   'amandarodriguez@example.com',
#   'Computer Science',
#   2024,
#   Decimal('3.10'),
#   'ME',
#   1,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2024, 6, 18, 6, 56, 44)),
#  (157,
#   'Linda',
#   'Lutz',
#   'dawn04@example.org',
#   'Business Administration',
#   2028,
#   Decimal('3.15'),
#   'AR',
#   1,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 5, 3, 6, 8, 47)),
#  (158,
#   'Allison',
#   'Harris',
#   'dianewilliamson@example.org',
#   'Psychology',
#   2025,
#   Decimal('3.69'),
#   'PR',
#   0,
#   'Sales',
#   'Research',
#   datetime.datetime(2024, 1, 5, 5, 42, 52)),
#  (159,
#   'Garrett',
#   'Levy',
#   'zachary40@example.com',
#   'Information Systems',
#   2026,
#   Decimal('3.70'),
#   'CT',
#   0,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2024, 11, 8, 14, 39, 39)),
#  (160,
#   'David',
#   'Willis',
#   'hstone@example.org',
#   'Marketing',
#   2028,
#   Decimal('3.69'),
#   'OR',
#   1,
#   'Sales',
#   'Customer Service',
#   datetime.datetime(2024, 2, 20, 5, 41, 5)),
#  (161,
#   'Kelly',
#   'Hawkins',
#   'theresafrancis@example.net',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.91'),
#   'VA',
#   0,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2025, 3, 28, 13, 26, 11)),
#  (162,
#   'Charles',
#   'Mayo',
#   'williamsdavid@example.net',
#   'Economics',
#   2026,
#   Decimal('3.77'),
#   'FL',
#   0,
#   'Data Analysis',
#   'Customer Service',
#   datetime.datetime(2025, 5, 18, 5, 48, 27)),
#  (163,
#   'Eric',
#   'Fletcher',
#   'samantha08@example.com',
#   'Business Administration',
#   2027,
#   Decimal('3.83'),
#   'IA',
#   0,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2024, 2, 19, 4, 8, 8)),
#  (164,
#   'Kevin',
#   'Barber',
#   'ubaker@example.net',
#   'Computer Science',
#   2025,
#   Decimal('3.26'),
#   'PR',
#   1,
#   'Product Management',
#   'Human Resources',
#   datetime.datetime(2025, 11, 9, 16, 1, 49)),
#  (165,
#   'Megan',
#   'Yu',
#   'sarah37@example.com',
#   'Accounting',
#   2024,
#   Decimal('3.25'),
#   'FL',
#   0,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 8, 19, 11, 18, 17)),
#  (166,
#   'Heather',
#   'Olson',
#   'tiffany24@example.com',
#   'Economics',
#   2024,
#   Decimal('2.50'),
#   'FL',
#   1,
#   'Product Management',
#   'Operations',
#   datetime.datetime(2025, 8, 12, 20, 50, 54)),
#  (167,
#   'Frank',
#   'Martin',
#   'dukecody@example.net',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.68'),
#   'PW',
#   0,
#   'Software Development',
#   'Research',
#   datetime.datetime(2025, 4, 25, 16, 7, 1)),
#  (168,
#   'Megan',
#   'Peterson',
#   'crystalperez@example.net',
#   'Business Administration',
#   2025,
#   Decimal('2.65'),
#   'AR',
#   0,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 9, 7, 9, 12, 9)),
#  (169,
#   'Kathleen',
#   'Andrews',
#   'heatherwood@example.com',
#   'Biology',
#   2025,
#   Decimal('3.75'),
#   'VT',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 9, 25, 0, 32, 19)),
#  (170,
#   'David',
#   'Obrien',
#   'xglover@example.org',
#   'Psychology',
#   2028,
#   Decimal('3.24'),
#   'LA',
#   1,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2024, 9, 29, 15, 27, 10)),
#  (171,
#   'Brett',
#   'Stokes',
#   'tyler98@example.com',
#   'Information Systems',
#   2026,
#   Decimal('3.89'),
#   'GA',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 11, 20, 12, 16, 40)),
#  (172,
#   'Jennifer',
#   'Hood',
#   'lynchhaley@example.com',
#   'Data Science',
#   2024,
#   Decimal('3.07'),
#   'MA',
#   0,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2024, 3, 29, 15, 40, 37)),
#  (173,
#   'Brett',
#   'Gardner',
#   'smithdavid@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.89'),
#   'NH',
#   0,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 8, 24, 9, 27, 47)),
#  (174,
#   'Jimmy',
#   'Warren',
#   'scottrobert@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.06'),
#   'TN',
#   0,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 15, 1, 50, 39)),
#  (175,
#   'Rachel',
#   'Ortega',
#   'arobinson@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.76'),
#   'NY',
#   1,
#   'Software Development',
#   'Finance',
#   datetime.datetime(2024, 11, 22, 10, 10, 14)),
#  (176,
#   'Sheila',
#   'Mays',
#   'taylorcatherine@example.org',
#   'Information Systems',
#   2026,
#   Decimal('3.23'),
#   'SC',
#   0,
#   'Research',
#   'Customer Service',
#   datetime.datetime(2025, 7, 5, 16, 29, 15)),
#  (177,
#   'Jeanne',
#   'Newton',
#   'shellyhernandez@example.com',
#   'Economics',
#   2025,
#   Decimal('3.46'),
#   'PR',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 8, 25, 5, 9, 40)),
#  (178,
#   'Robin',
#   'Thompson',
#   'randy22@example.com',
#   'Finance',
#   2025,
#   Decimal('3.15'),
#   'KY',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 1, 20, 3, 27, 26)),
#  (179,
#   'Donna',
#   'Moore',
#   'michael20@example.com',
#   'Economics',
#   2026,
#   Decimal('2.68'),
#   'AR',
#   1,
#   'Product Management',
#   'Customer Service',
#   datetime.datetime(2025, 10, 10, 13, 48, 58)),
#  (180,
#   'George',
#   'Morton',
#   'contreraskelly@example.org',
#   'Business Administration',
#   2024,
#   Decimal('3.77'),
#   'TN',
#   1,
#   'Marketing',
#   'Research',
#   datetime.datetime(2025, 10, 26, 12, 16, 39)),
#  (181,
#   'Travis',
#   'Moore',
#   'daisyjohnson@example.com',
#   'Psychology',
#   2026,
#   Decimal('3.86'),
#   'CO',
#   0,
#   'Customer Service',
#   'Research',
#   datetime.datetime(2025, 10, 9, 16, 16, 29)),
#  (182,
#   'Brian',
#   'Roberson',
#   'hquinn@example.net',
#   'Computer Science',
#   2027,
#   Decimal('2.62'),
#   'MD',
#   0,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2025, 11, 7, 21, 38, 53)),
#  (183,
#   'Kelly',
#   'Hurst',
#   'amandabrady@example.com',
#   'Biology',
#   2028,
#   Decimal('3.57'),
#   'ID',
#   0,
#   'Product Management',
#   'Research',
#   datetime.datetime(2024, 8, 24, 1, 7, 1)),
#  (184,
#   'Erin',
#   'Richardson',
#   'keithharrison@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('2.52'),
#   'AS',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 2, 22, 21, 16, 36)),
#  (185,
#   'Colleen',
#   'Patterson',
#   'wburgess@example.com',
#   'Marketing',
#   2028,
#   Decimal('3.28'),
#   'MI',
#   0,
#   'Customer Service',
#   'Finance',
#   datetime.datetime(2024, 1, 16, 12, 6, 44)),
#  (186,
#   'William',
#   'Boyd',
#   'mrobles@example.net',
#   'Economics',
#   2026,
#   Decimal('2.99'),
#   'PW',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 10, 29, 7, 42, 47)),
#  (187,
#   'Gregory',
#   'Weiss',
#   'sthomas@example.org',
#   'Psychology',
#   2025,
#   Decimal('3.91'),
#   'AZ',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 10, 11, 5, 25, 35)),
#  (188,
#   'Joseph',
#   'Wheeler',
#   'derrick19@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.97'),
#   'NE',
#   1,
#   'Engineering',
#   'Finance',
#   datetime.datetime(2025, 11, 2, 16, 19, 38)),
#  (189,
#   'Evan',
#   'Sanders',
#   'debra51@example.net',
#   'Accounting',
#   2026,
#   Decimal('2.75'),
#   'IA',
#   0,
#   'Human Resources',
#   'Finance',
#   datetime.datetime(2024, 8, 25, 23, 29, 38)),
#  (190,
#   'Alexandra',
#   'Mcdaniel',
#   'bakertracey@example.com',
#   'Biology',
#   2028,
#   Decimal('3.21'),
#   'HI',
#   0,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2025, 1, 13, 1, 8, 29)),
#  (191,
#   'Rachel',
#   'Smith',
#   'rbrady@example.org',
#   'Mechanical Engineering',
#   2024,
#   Decimal('2.68'),
#   'MH',
#   0,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 23, 3, 36, 2)),
#  (192,
#   'Cheryl',
#   'Parker',
#   'ahall@example.org',
#   'Computer Science',
#   2027,
#   Decimal('3.81'),
#   'MS',
#   0,
#   'Product Management',
#   'Engineering',
#   datetime.datetime(2024, 2, 3, 11, 18, 9)),
#  (193,
#   'John',
#   'Harris',
#   'jordan71@example.com',
#   'Business Administration',
#   2028,
#   Decimal('2.96'),
#   'FM',
#   0,
#   'Marketing',
#   'Sales',
#   datetime.datetime(2025, 5, 24, 18, 24, 2)),
#  (194,
#   'Howard',
#   'Brock',
#   'erodriguez@example.net',
#   'Business Administration',
#   2025,
#   Decimal('3.15'),
#   'SC',
#   1,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2025, 2, 26, 8, 53, 13)),
#  (195,
#   'Ashley',
#   'Grimes',
#   'lstout@example.net',
#   'Computer Science',
#   2027,
#   Decimal('2.54'),
#   'SD',
#   0,
#   'Human Resources',
#   'Engineering',
#   datetime.datetime(2024, 10, 28, 4, 21, 24)),
#  (196,
#   'Darrell',
#   'Phillips',
#   'jsmith@example.com',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.68'),
#   'DE',
#   1,
#   'Research',
#   'Sales',
#   datetime.datetime(2024, 5, 14, 5, 11)),
#  (197,
#   'Anthony',
#   'Powell',
#   'scottstevens@example.net',
#   'Marketing',
#   2027,
#   Decimal('2.95'),
#   'ID',
#   0,
#   'Data Analysis',
#   'Software Development',
#   datetime.datetime(2024, 11, 6, 14, 23, 57)),
#  (198,
#   'Tiffany',
#   'Tyler',
#   'glloyd@example.com',
#   'Business Administration',
#   2025,
#   Decimal('3.47'),
#   'MN',
#   1,
#   'Sales',
#   'Software Development',
#   datetime.datetime(2025, 5, 22, 21, 34, 36)),
#  (199,
#   'Michael',
#   'Taylor',
#   'sawyeranita@example.com',
#   'Marketing',
#   2025,
#   Decimal('2.71'),
#   'FM',
#   0,
#   'Software Development',
#   'Research',
#   datetime.datetime(2025, 8, 5, 18, 46, 34)),
#  (200,
#   'Pamela',
#   'White',
#   'joshua55@example.org',
#   'Business Administration',
#   2024,
#   Decimal('2.66'),
#   'CT',
#   1,
#   'Product Management',
#   'Customer Service',
#   datetime.datetime(2024, 6, 10, 15, 7, 45))]

# %% [markdown]
# Use Case 1

# %%
sql_file = "../schema/use_case_1.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#    position_id         title location required_experience work_mode  \
# 0          111  Chiropractor       MA             2 years    Hybrid
#
#           company_name job_category
# 0  Harris, Bell and Yu    Marketing
# Use Case executed

# %% [markdown]
# Use Case 2

# %%
sql_file = "../schema/use_case_2.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#     position_id                                  title location  \
# 0            63  Senior tax professional/tax inspector       ID
# 1           151            Industrial/product designer       VA
# 2           198                    Scientist, forensic       RI
# 3            91               Surveyor, land/geomatics       IN
# 4           152                    Trade mark attorney       VT
# 5            25        Producer, television/film/video       RI
# 6           187                          Haematologist       GA
# 7            27                             Counsellor       AL
# 8            38                         Science writer       VI
# 9           163           Administrator, Civil Service       WA
# 10          182  Medical laboratory scientific officer       UT
#
#    required_experience                  company_name required_major
# 0              0 years                Moran and Sons     Accounting
# 1              4 years                    Malone Ltd     Accounting
# 2              5 years       Duarte, Brown and Stout     Accounting
# 3              3 years                  Rivera-Perry     Accounting
# 4              2 years              Johnson and Sons     Accounting
# 5              4 years              Wilkerson-Harper     Accounting
# 6              0 years       Crane, Cain and Edwards     Accounting
# 7              0 years    Walls, Murphy and Garrison     Accounting
# 8              3 years                  Greene-Jones     Accounting
# 9              1 years                     Burke Ltd     Accounting
# 10             4 years  Reynolds, Crawford and Lopez     Accounting
# Use Case executed

# %% [markdown]
# Use Case 3

# %%
sql_file = "../schema/use_case_3.sql"

cur.execute("DROP PROCEDURE IF EXISTS Apply_For_Position")

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

try: cur.execute("CALL Apply_For_Position(4, 198)")
except Exception as e: print(e)

cur.execute("CALL Apply_For_Position(3, 198)")
cur.execute("SELECT * FROM Application ORDER BY application_id DESC LIMIT 1")

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)

db.commit()
print("Use Case executed")
# Out:
# SQL file loaded
# 1644 (HY000): This position required major is Accounting
#    application_id  user_id  position_id application_date     status notes
# 0            5908        3          198       2025-11-30  Submitted  None
# Use Case executed

# %% [markdown]
# Use Case 4

# %%
sql_file = "../schema/use_case_4.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#    num_applications
# 0                21
# Use Case executed

# %% [markdown]
# Use Case 5

# %%
sql_file = "../schema/use_case_5.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#      gpa   first_name   last_name
# 0   3.96        Brent     Johnson
# 1   3.93        Tracy     Kennedy
# 2   3.86      Shannon        Wall
# 3   3.84       Steven      Miller
# 4   3.84  Christopher      Miller
# 5   3.81      Jessica     Mcclure
# 6   3.79       Austin       Ortiz
# 7   3.60     Samantha        West
# 8   3.58      Breanna        Webb
# 9   3.53        Jacob       Cantu
# 10  3.44      Melissa      Castro
# 11  3.43         Lisa     Wheeler
# 12  3.33      Shannon       Mayer
# 13  3.32       Rhonda      Miller
# 14  3.25        Megan          Yu
# 15  3.08      Melissa   Jefferson
# 16  2.75       Nicole        Shaw
# 17  2.75         Evan     Sanders
# 18  2.73        Karen   Patterson
# 19  2.66        Jason      Hanson
# 20  2.52         Erin  Richardson
# Use Case executed

# %% [markdown]
# Use Case 6

# %%
sql_file = "../schema/use_case_6.sql"

cur.execute("DROP TRIGGER IF EXISTS Notify_Matching_Majors;")

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)
    
print("Use Case executed")
# Out:
# SQL file loaded
# Use Case executed

# %% [markdown]
# Testing the trigger

# %%
sql_file = "../schema/use_case_6_test.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

position_id = cur.lastrowid

cur.execute("""
    SELECT u.first_name, u.last_name, u.major, a.notes
    FROM Application a
    JOIN Users u ON a.user_id = u.user_id
    WHERE a.position_id = %s
""", (position_id,))

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
# Out:
# SQL file loaded
#    first_name  last_name    major  \
# 0        Erik      Smith  Biology
# 1     Maureen    Roberts  Biology
# 2     Tiffany   Hamilton  Biology
# 3      Meagan      Lewis  Biology
# 4      Rhonda     Miller  Biology
# 5      Daniel   Phillips  Biology
# 6        Greg   Robinson  Biology
# 7        Tony     Jacobs  Biology
# 8      Hannah       Horn  Biology
# 9   Christina  Velazquez  Biology
# 10      Larry      Ramos  Biology
# 11       John     Forbes  Biology
# 12   Kathleen    Andrews  Biology
# 13      Kelly      Hurst  Biology
# 14  Alexandra   Mcdaniel  Biology
#
#                                                 notes
# 0   Erik! A new position is available: Biology Res...
# 1   Maureen! A new position is available: Biology ...
# 2   Tiffany! A new position is available: Biology ...
# 3   Meagan! A new position is available: Biology R...
# 4   Rhonda! A new position is available: Biology R...
# 5   Daniel! A new position is available: Biology R...
# 6   Greg! A new position is available: Biology Res...
# 7   Tony! A new position is available: Biology Res...
# 8   Hannah! A new position is available: Biology R...
# 9   Christina! A new position is available: Biolog...
# 10  Larry! A new position is available: Biology Re...
# 11  John! A new position is available: Biology Res...
# 12  Kathleen! A new position is available: Biology...
# 13  Kelly! A new position is available: Biology Re...
# 14  Alexandra! A new position is available: Biolog...

# %% [markdown]
# Close cursor and database

# %%
cur.close()
db.close()
print("All Use Cases executed successfully.")
# Out:
# All Use Cases executed successfully.
