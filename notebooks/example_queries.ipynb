# %% [markdown]
# # Example Use Queries

# %% [markdown]
# Import libraries.

# %%
import mysql.connector
from dotenv import load_dotenv
import os
import pandas as pd

# %% [markdown]
# Load enviornment variables.

# %%
load_dotenv()

HOST = os.getenv("MYSQL_HOST", "localhost")
USER = os.getenv("MYSQL_USER", "root")
PASSWORD = os.getenv("MYSQL_PASSWORD")

# %% [markdown]
# Connect to mysql server

# %%
db = mysql.connector.connect(
    host=HOST,
    user=USER,              
    password=PASSWORD
)
cur = db.cursor()
print("Connected!")
cur.execute("USE HuskiesJob")
cur.execute("SELECT * FROM Users")
cur.fetchall()
# Out:
# Connected!
# [(1,
#   'Chris',
#   'Lewis',
#   'holly37@example.org',
#   'Data Science',
#   2025,
#   Decimal('2.72'),
#   'VA',
#   1,
#   'Customer Service',
#   'Software Development',
#   datetime.datetime(2024, 1, 1, 10, 53, 42)),
#  (2,
#   'Craig',
#   'Hicks',
#   'millsshirley@example.com',
#   'Accounting',
#   2024,
#   Decimal('2.65'),
#   'MN',
#   0,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 3, 13, 11, 40, 29)),
#  (3,
#   'Aaron',
#   'Campos',
#   'aliciawashington@example.org',
#   'Accounting',
#   2027,
#   Decimal('3.06'),
#   'MP',
#   1,
#   'Engineering',
#   'Marketing',
#   datetime.datetime(2024, 7, 13, 1, 48, 23)),
#  (4,
#   'Stephanie',
#   'Harris',
#   'cookaustin@example.net',
#   'Psychology',
#   2024,
#   Decimal('3.23'),
#   'DE',
#   1,
#   'Finance',
#   'Sales',
#   datetime.datetime(2025, 6, 19, 17, 7, 51)),
#  (5,
#   'Erik',
#   'Smith',
#   'dorseyangela@example.org',
#   'Biology',
#   2024,
#   Decimal('3.00'),
#   'GA',
#   1,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2024, 11, 30, 0, 30, 50)),
#  (6,
#   'Kyle',
#   'Mcfarland',
#   'amandahess@example.com',
#   'Accounting',
#   2025,
#   Decimal('3.16'),
#   'OK',
#   0,
#   'Software Development',
#   'Software Development',
#   datetime.datetime(2025, 2, 21, 21, 6, 28)),
#  (7,
#   'Barbara',
#   'Carrillo',
#   'jermaine51@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.84'),
#   'TN',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 10, 8, 16, 48, 19)),
#  (8,
#   'Maureen',
#   'Roberts',
#   'mcguirealbert@example.org',
#   'Biology',
#   2025,
#   Decimal('3.30'),
#   'NV',
#   0,
#   'Product Management',
#   'Product Management',
#   datetime.datetime(2024, 4, 7, 1, 2, 12)),
#  (9,
#   'Jacqueline',
#   'Davis',
#   'andersonjordan@example.net',
#   'Economics',
#   2024,
#   Decimal('3.66'),
#   'ME',
#   0,
#   'Sales',
#   'Finance',
#   datetime.datetime(2024, 3, 24, 13, 33, 47)),
#  (10,
#   'Patrick',
#   'Lee',
#   'burnswilliam@example.net',
#   'Mechanical Engineering',
#   2024,
#   Decimal('2.87'),
#   'UT',
#   0,
#   'Finance',
#   'Human Resources',
#   datetime.datetime(2024, 8, 12, 17, 51, 20)),
#  (11,
#   'Stephanie',
#   'Vasquez',
#   'christinewarren@example.net',
#   'Accounting',
#   2024,
#   Decimal('3.69'),
#   'IN',
#   1,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2024, 5, 25, 15, 12, 32)),
#  (12,
#   'Patrick',
#   'Carpenter',
#   'james82@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.80'),
#   'TX',
#   1,
#   'Supply Chain',
#   'Finance',
#   datetime.datetime(2025, 8, 31, 20, 24, 44)),
#  (13,
#   'Michael',
#   'Wood',
#   'tammyporter@example.org',
#   'Computer Science',
#   2028,
#   Decimal('2.95'),
#   'AL',
#   0,
#   'Software Development',
#   'Sales',
#   datetime.datetime(2025, 3, 7, 2, 23, 33)),
#  (14,
#   'Melissa',
#   'Jackson',
#   'kimberly63@example.com',
#   'Economics',
#   2024,
#   Decimal('3.23'),
#   'MO',
#   0,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 2, 5, 4, 23)),
#  (15,
#   'Tiffany',
#   'Hamilton',
#   'kevin83@example.org',
#   'Biology',
#   2025,
#   Decimal('3.43'),
#   'WI',
#   1,
#   'Sales',
#   'Human Resources',
#   datetime.datetime(2025, 5, 22, 19, 57, 28)),
#  (16,
#   'Breanna',
#   'Webb',
#   'nicholas09@example.org',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.58'),
#   'FM',
#   1,
#   'Engineering',
#   'Marketing',
#   datetime.datetime(2023, 12, 5, 9, 58, 36)),
#  (17,
#   'Brandon',
#   'Harper',
#   'emilycannon@example.com',
#   'Economics',
#   2026,
#   Decimal('3.47'),
#   'IN',
#   1,
#   'Product Management',
#   'Sales',
#   datetime.datetime(2024, 2, 29, 9, 7, 17)),
#  (18,
#   'Ricardo',
#   'Lee',
#   'jerryramos@example.com',
#   'Computer Science',
#   2027,
#   Decimal('2.54'),
#   'TX',
#   1,
#   'Product Management',
#   'Marketing',
#   datetime.datetime(2025, 11, 3, 20, 6, 12)),
#  (19,
#   'Anthony',
#   'Marshall',
#   'allen12@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.88'),
#   'CO',
#   0,
#   'Human Resources',
#   'Data Analysis',
#   datetime.datetime(2025, 6, 19, 6, 6, 51)),
#  (20,
#   'Nicole',
#   'Shaw',
#   'karen14@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.75'),
#   'HI',
#   0,
#   'Finance',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 30, 16, 37, 33)),
#  (21,
#   'Wesley',
#   'Jones',
#   'stephaniesmith@example.org',
#   'Accounting',
#   2028,
#   Decimal('3.97'),
#   'IA',
#   1,
#   'Marketing',
#   'Research',
#   datetime.datetime(2024, 8, 5, 20, 36, 3)),
#  (22,
#   'Michael',
#   'Lucas',
#   'jacob09@example.net',
#   'Economics',
#   2026,
#   Decimal('3.22'),
#   'MN',
#   0,
#   'Human Resources',
#   'Data Analysis',
#   datetime.datetime(2023, 12, 11, 10, 6, 40)),
#  (23,
#   'Andrew',
#   'Dixon',
#   'danielmaldonado@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.95'),
#   'PW',
#   1,
#   'Software Development',
#   'Software Development',
#   datetime.datetime(2024, 5, 26, 7, 24, 34)),
#  (24,
#   'Nicholas',
#   'Kennedy',
#   'sethpadilla@example.org',
#   'Economics',
#   2025,
#   Decimal('3.51'),
#   'ME',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 2, 9, 0, 16, 51)),
#  (25,
#   'Diane',
#   'Sherman',
#   'morrissylvia@example.com',
#   'Data Science',
#   2027,
#   Decimal('2.98'),
#   'SD',
#   1,
#   'Sales',
#   'Product Management',
#   datetime.datetime(2024, 3, 31, 5, 32, 34)),
#  (26,
#   'Meagan',
#   'Lewis',
#   'amanda10@example.net',
#   'Biology',
#   2024,
#   Decimal('3.18'),
#   'MN',
#   1,
#   'Software Development',
#   'Customer Service',
#   datetime.datetime(2025, 7, 14, 6, 25, 29)),
#  (27,
#   'Kimberly',
#   'Taylor',
#   'kenneth30@example.net',
#   'Finance',
#   2024,
#   Decimal('3.32'),
#   'NV',
#   1,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2024, 3, 30, 8, 8, 22)),
#  (28,
#   'Edward',
#   'Hartman',
#   'nsanchez@example.org',
#   'Accounting',
#   2024,
#   Decimal('3.25'),
#   'AS',
#   0,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 9, 3, 3, 50, 16)),
#  (29,
#   'Cathy',
#   'Bradley',
#   'campbelldavid@example.com',
#   'Finance',
#   2028,
#   Decimal('2.77'),
#   'NC',
#   1,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 10, 25, 6, 34, 13)),
#  (30,
#   'Tracy',
#   'Kennedy',
#   'elliottlindsey@example.com',
#   'Data Science',
#   2025,
#   Decimal('3.93'),
#   'KS',
#   1,
#   'Software Development',
#   'Sales',
#   datetime.datetime(2025, 10, 1, 0, 16, 34)),
#  (31,
#   'Jennifer',
#   'Leach',
#   'rebeccabailey@example.org',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.57'),
#   'MH',
#   0,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 8, 28, 15, 31, 38)),
#  (32,
#   'Nicolas',
#   'Gonzalez',
#   'sotocarolyn@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.54'),
#   'MN',
#   1,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 2, 20, 23, 43, 5)),
#  (33,
#   'Betty',
#   'Rosales',
#   'joshua39@example.com',
#   'Psychology',
#   2024,
#   Decimal('3.63'),
#   'LA',
#   1,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2024, 10, 22, 20, 5, 1)),
#  (34,
#   'Elizabeth',
#   'Garrett',
#   'swiggins@example.org',
#   'Information Systems',
#   2025,
#   Decimal('3.07'),
#   'CO',
#   0,
#   'Software Development',
#   'Supply Chain',
#   datetime.datetime(2025, 2, 3, 1, 37, 19)),
#  (35,
#   'Christina',
#   'Bailey',
#   'sgonzalez@example.org',
#   'Information Systems',
#   2028,
#   Decimal('3.83'),
#   'DE',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2025, 4, 2, 13, 19, 1)),
#  (36,
#   'Joy',
#   'Oneal',
#   'richardcannon@example.org',
#   'Marketing',
#   2025,
#   Decimal('2.96'),
#   'VA',
#   0,
#   'Sales',
#   'Software Development',
#   datetime.datetime(2024, 4, 5, 11, 35, 20)),
#  (37,
#   'Marissa',
#   'Hawkins',
#   'gregoryortiz@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.94'),
#   'ND',
#   0,
#   'Supply Chain',
#   'Marketing',
#   datetime.datetime(2024, 9, 26, 14, 40, 17)),
#  (38,
#   'Veronica',
#   'Lopez',
#   'scottgrant@example.org',
#   'Economics',
#   2025,
#   Decimal('3.21'),
#   'DE',
#   1,
#   'Software Development',
#   'Engineering',
#   datetime.datetime(2025, 8, 22, 4, 14, 51)),
#  (39,
#   'Mary',
#   'Dennis',
#   'matthew82@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.71'),
#   'NM',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 3, 18, 18, 20, 51)),
#  (40,
#   'Sheryl',
#   'Patterson',
#   'howardrobert@example.org',
#   'Accounting',
#   2025,
#   Decimal('2.50'),
#   'IN',
#   0,
#   'Marketing',
#   'Marketing',
#   datetime.datetime(2024, 3, 21, 3, 50, 21)),
#  (41,
#   'Steven',
#   'Santiago',
#   'mmartinez@example.com',
#   'Computer Science',
#   2025,
#   Decimal('3.13'),
#   'NH',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2025, 8, 1, 3, 32, 26)),
#  (42,
#   'Jason',
#   'Allen',
#   'hallanna@example.org',
#   'Economics',
#   2028,
#   Decimal('3.65'),
#   'PW',
#   0,
#   'Marketing',
#   'Finance',
#   datetime.datetime(2025, 1, 7, 14, 40, 11)),
#  (43,
#   'Steven',
#   'Miller',
#   'christophermata@example.com',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.84'),
#   'MT',
#   0,
#   'Customer Service',
#   'Product Management',
#   datetime.datetime(2025, 8, 13, 20, 6, 9)),
#  (44,
#   'Craig',
#   'Simmons',
#   'calebbeck@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.84'),
#   'UT',
#   0,
#   'Human Resources',
#   'Finance',
#   datetime.datetime(2024, 9, 24, 12, 28, 20)),
#  (45,
#   'Shannon',
#   'Wall',
#   'herringstephanie@example.com',
#   'Accounting',
#   2025,
#   Decimal('3.86'),
#   'GA',
#   0,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 7, 16, 4, 24, 29)),
#  (46,
#   'Claire',
#   'Bryant',
#   'rcole@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.40'),
#   'PR',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 2, 4, 9, 36, 11)),
#  (47,
#   'Kenneth',
#   'Mcdaniel',
#   'porterchristopher@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.36'),
#   'IL',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2025, 4, 2, 13, 55, 16)),
#  (48,
#   'Bradley',
#   'Williams',
#   'chris10@example.org',
#   'Finance',
#   2026,
#   Decimal('2.61'),
#   'ID',
#   0,
#   'Finance',
#   'Human Resources',
#   datetime.datetime(2024, 12, 9, 4, 33, 40)),
#  (49,
#   'Charles',
#   'Nelson',
#   'jacobspaul@example.org',
#   'Information Systems',
#   2024,
#   Decimal('3.44'),
#   'NY',
#   0,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 4, 8, 7, 48, 13)),
#  (50,
#   'Shannon',
#   'Mayer',
#   'esparzalinda@example.com',
#   'Computer Science',
#   2024,
#   Decimal('3.33'),
#   'ME',
#   1,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2025, 6, 5, 15, 14, 58)),
#  (51,
#   'Allen',
#   'Evans',
#   'jamesalexander@example.com',
#   'Marketing',
#   2025,
#   Decimal('2.68'),
#   'TX',
#   1,
#   'Engineering',
#   'Research',
#   datetime.datetime(2025, 11, 29, 20, 27, 40)),
#  (52,
#   'Scott',
#   'Ryan',
#   'dominique90@example.org',
#   'Business Administration',
#   2027,
#   Decimal('3.69'),
#   'FL',
#   1,
#   'Research',
#   'Marketing',
#   datetime.datetime(2024, 4, 23, 15, 19, 5)),
#  (53,
#   'April',
#   'Morrison',
#   'jayhernandez@example.net',
#   'Psychology',
#   2028,
#   Decimal('3.56'),
#   'AL',
#   1,
#   'Marketing',
#   'Human Resources',
#   datetime.datetime(2025, 8, 21, 16, 37, 59)),
#  (54,
#   'Rhonda',
#   'Miller',
#   'meganmiller@example.org',
#   'Biology',
#   2028,
#   Decimal('3.32'),
#   'NV',
#   1,
#   'Marketing',
#   'Finance',
#   datetime.datetime(2025, 4, 6, 3, 33, 32)),
#  (55,
#   'Kevin',
#   'Wolf',
#   'taylor26@example.org',
#   'Information Systems',
#   2025,
#   Decimal('3.16'),
#   'AL',
#   1,
#   'Data Analysis',
#   'Marketing',
#   datetime.datetime(2024, 8, 20, 18, 34, 55)),
#  (56,
#   'Christine',
#   'Herrera',
#   'scombs@example.net',
#   'Accounting',
#   2026,
#   Decimal('3.00'),
#   'WI',
#   1,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 12, 10, 8, 17, 24)),
#  (57,
#   'Stacy',
#   'Perez',
#   'kelsey70@example.com',
#   'Business Administration',
#   2028,
#   Decimal('3.14'),
#   'WY',
#   1,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2025, 10, 25, 14, 50, 59)),
#  (58,
#   'John',
#   'Henderson',
#   'bradleyvaughn@example.org',
#   'Accounting',
#   2024,
#   Decimal('2.83'),
#   'NH',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 3, 5, 1, 50, 15)),
#  (59,
#   'Daniel',
#   'Phillips',
#   'acaldwell@example.net',
#   'Biology',
#   2024,
#   Decimal('3.34'),
#   'CA',
#   0,
#   'Customer Service',
#   'Sales',
#   datetime.datetime(2023, 12, 8, 4, 50, 27)),
#  (60,
#   'Angelica',
#   'Stein',
#   'zgrant@example.net',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.88'),
#   'MS',
#   1,
#   'Sales',
#   'Human Resources',
#   datetime.datetime(2024, 12, 3, 0, 7, 9)),
#  (61,
#   'Gregory',
#   'Salazar',
#   'elainemassey@example.com',
#   'Psychology',
#   2026,
#   Decimal('2.63'),
#   'NY',
#   0,
#   'Research',
#   'Data Analysis',
#   datetime.datetime(2025, 3, 31, 12, 33, 8)),
#  (62,
#   'Greg',
#   'Robinson',
#   'santosrachel@example.net',
#   'Biology',
#   2025,
#   Decimal('2.64'),
#   'IL',
#   0,
#   'Operations',
#   'Human Resources',
#   datetime.datetime(2024, 7, 10, 20, 30, 26)),
#  (63,
#   'Julie',
#   'Evans',
#   'robin29@example.org',
#   'Data Science',
#   2027,
#   Decimal('3.95'),
#   'UT',
#   1,
#   'Data Analysis',
#   'Customer Service',
#   datetime.datetime(2024, 4, 14, 22, 22, 59)),
#  (64,
#   'Kelsey',
#   'Frey',
#   'emilyhudson@example.org',
#   'Information Systems',
#   2024,
#   Decimal('3.55'),
#   'AZ',
#   0,
#   'Human Resources',
#   'Software Development',
#   datetime.datetime(2024, 9, 29, 14, 48, 44)),
#  (65,
#   'Patricia',
#   'Padilla',
#   'stacy84@example.net',
#   'Marketing',
#   2026,
#   Decimal('3.91'),
#   'MS',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 8, 7, 22, 47, 17)),
#  (66,
#   'Tony',
#   'Jacobs',
#   'stephen87@example.net',
#   'Biology',
#   2027,
#   Decimal('3.55'),
#   'WA',
#   0,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2023, 12, 13, 8, 48, 23)),
#  (67,
#   'Dennis',
#   'Riley',
#   'masonangela@example.net',
#   'Finance',
#   2024,
#   Decimal('3.53'),
#   'NE',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 6, 8, 5, 18, 19)),
#  (68,
#   'Mark',
#   'Davis',
#   'anna74@example.net',
#   'Data Science',
#   2027,
#   Decimal('2.81'),
#   'TX',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2024, 9, 5, 10, 14, 12)),
#  (69,
#   'Alexa',
#   'Rogers',
#   'maryclark@example.com',
#   'Finance',
#   2024,
#   Decimal('3.17'),
#   'PR',
#   1,
#   'Software Development',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 12, 5, 27, 39)),
#  (70,
#   'Rebecca',
#   'Trujillo',
#   'eric07@example.com',
#   'Information Systems',
#   2024,
#   Decimal('2.79'),
#   'DE',
#   0,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2025, 7, 19, 3, 31)),
#  (71,
#   'Erica',
#   'Mcneil',
#   'laurenking@example.org',
#   'Finance',
#   2024,
#   Decimal('3.41'),
#   'NH',
#   0,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 6, 2, 15, 39, 24)),
#  (72,
#   'John',
#   'Wright',
#   'michael05@example.net',
#   'Psychology',
#   2027,
#   Decimal('3.05'),
#   'MT',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2025, 4, 4, 19, 44, 48)),
#  (73,
#   'Hannah',
#   'Horn',
#   'banksmary@example.net',
#   'Biology',
#   2026,
#   Decimal('3.56'),
#   'IL',
#   0,
#   'Finance',
#   'Operations',
#   datetime.datetime(2025, 1, 25, 14, 58, 36)),
#  (74,
#   'Henry',
#   'Turner',
#   'garywarner@example.com',
#   'Marketing',
#   2025,
#   Decimal('3.64'),
#   'NE',
#   0,
#   'Human Resources',
#   'Supply Chain',
#   datetime.datetime(2024, 1, 17, 13, 43, 30)),
#  (75,
#   'Christina',
#   'Velazquez',
#   'qsteele@example.net',
#   'Biology',
#   2025,
#   Decimal('3.31'),
#   'VA',
#   0,
#   'Supply Chain',
#   'Supply Chain',
#   datetime.datetime(2024, 11, 11, 2, 58, 6)),
#  (76,
#   'Jake',
#   'Mccarty',
#   'malonevalerie@example.net',
#   'Economics',
#   2024,
#   Decimal('2.61'),
#   'IL',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2025, 6, 26, 12, 2, 43)),
#  (77,
#   'John',
#   'Williams',
#   'peter93@example.com',
#   'Computer Science',
#   2025,
#   Decimal('2.83'),
#   'WY',
#   1,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2025, 7, 15, 4, 29, 28)),
#  (78,
#   'Alexandra',
#   'Howard',
#   'michele10@example.com',
#   'Computer Science',
#   2028,
#   Decimal('2.63'),
#   'MT',
#   1,
#   'Marketing',
#   'Data Analysis',
#   datetime.datetime(2024, 10, 7, 17, 39, 54)),
#  (79,
#   'Andrew',
#   'Larson',
#   'brennancrystal@example.org',
#   'Business Administration',
#   2024,
#   Decimal('3.16'),
#   'VT',
#   0,
#   'Research',
#   'Software Development',
#   datetime.datetime(2025, 5, 9, 17, 9, 47)),
#  (80,
#   'Jeffrey',
#   'Johnson',
#   'djordan@example.org',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.43'),
#   'NC',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 10, 9, 13, 39, 5)),
#  (81,
#   'Lisa',
#   'Wheeler',
#   'james35@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.43'),
#   'LA',
#   0,
#   'Human Resources',
#   'Product Management',
#   datetime.datetime(2025, 8, 11, 22, 18, 56)),
#  (82,
#   'Marcus',
#   'Espinoza',
#   'davidpugh@example.org',
#   'Finance',
#   2028,
#   Decimal('3.66'),
#   'SC',
#   1,
#   'Engineering',
#   'Operations',
#   datetime.datetime(2025, 6, 7, 6, 25, 26)),
#  (83,
#   'Rodney',
#   'Fernandez',
#   'terrycorey@example.com',
#   'Computer Science',
#   2027,
#   Decimal('2.53'),
#   'WV',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 3, 26, 10, 23, 27)),
#  (84,
#   'Joshua',
#   'Perry',
#   'cindy96@example.org',
#   'Computer Science',
#   2026,
#   Decimal('3.53'),
#   'KS',
#   1,
#   'Customer Service',
#   'Data Analysis',
#   datetime.datetime(2024, 2, 6, 6, 59, 30)),
#  (85,
#   'Amy',
#   'Mills',
#   'hollyhayes@example.com',
#   'Data Science',
#   2026,
#   Decimal('2.94'),
#   'ND',
#   0,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2024, 12, 21, 9, 48, 6)),
#  (86,
#   'Jennifer',
#   'Taylor',
#   'delgadokimberly@example.net',
#   'Computer Science',
#   2028,
#   Decimal('3.94'),
#   'AR',
#   1,
#   'Engineering',
#   'Customer Service',
#   datetime.datetime(2025, 11, 12, 20, 13, 45)),
#  (87,
#   'Ruben',
#   'Kelly',
#   'wardleonard@example.net',
#   'Accounting',
#   2027,
#   Decimal('3.34'),
#   'CT',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 9, 18, 23, 39, 42)),
#  (88,
#   'Jorge',
#   'Thompson',
#   'egreene@example.com',
#   'Data Science',
#   2028,
#   Decimal('3.16'),
#   'HI',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 6, 10, 16, 36, 35)),
#  (89,
#   'David',
#   'Baldwin',
#   'william08@example.net',
#   'Economics',
#   2025,
#   Decimal('2.57'),
#   'MA',
#   0,
#   'Research',
#   'Software Development',
#   datetime.datetime(2024, 6, 3, 17, 42, 35)),
#  (90,
#   'James',
#   'Russell',
#   'yatesnicole@example.org',
#   'Information Systems',
#   2025,
#   Decimal('2.93'),
#   'MA',
#   0,
#   'Finance',
#   'Supply Chain',
#   datetime.datetime(2024, 1, 11, 17, 57, 26)),
#  (91,
#   'Valerie',
#   'Barrett',
#   'marcusvazquez@example.net',
#   'Business Administration',
#   2028,
#   Decimal('2.87'),
#   'NC',
#   1,
#   'Research',
#   'Engineering',
#   datetime.datetime(2024, 4, 14, 13, 29, 1)),
#  (92,
#   'Brandy',
#   'Wolfe',
#   'rowedarrell@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.36'),
#   'FL',
#   1,
#   'Software Development',
#   'Human Resources',
#   datetime.datetime(2025, 5, 17, 6, 46, 49)),
#  (93,
#   'Christopher',
#   'Miller',
#   'brentlawson@example.org',
#   'Marketing',
#   2024,
#   Decimal('3.84'),
#   'DE',
#   0,
#   'Engineering',
#   'Human Resources',
#   datetime.datetime(2024, 3, 29, 1, 16, 40)),
#  (94,
#   'Larry',
#   'Ramos',
#   'briggssteven@example.net',
#   'Biology',
#   2028,
#   Decimal('2.94'),
#   'KS',
#   0,
#   'Finance',
#   'Research',
#   datetime.datetime(2024, 9, 18, 20, 56, 51)),
#  (95,
#   'Kaitlyn',
#   'Marshall',
#   'pvelazquez@example.net',
#   'Psychology',
#   2027,
#   Decimal('3.61'),
#   'WY',
#   1,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 3, 18, 11, 26, 52)),
#  (96,
#   'Elizabeth',
#   'Oconnor',
#   'alyssa24@example.com',
#   'Information Systems',
#   2024,
#   Decimal('3.25'),
#   'TX',
#   0,
#   'Sales',
#   'Operations',
#   datetime.datetime(2025, 6, 10, 20, 49, 44)),
#  (97,
#   'Jacob',
#   'Cantu',
#   'zsmith@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('3.53'),
#   'RI',
#   1,
#   'Customer Service',
#   'Finance',
#   datetime.datetime(2024, 5, 5, 4, 45, 34)),
#  (98,
#   'John',
#   'Moore',
#   'rebecca23@example.org',
#   'Information Systems',
#   2026,
#   Decimal('3.28'),
#   'NC',
#   0,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2024, 7, 28, 3, 30, 57)),
#  (99,
#   'Austin',
#   'Ortiz',
#   'larsondeborah@example.org',
#   'Electrical Engineering',
#   2025,
#   Decimal('3.79'),
#   'DC',
#   0,
#   'Sales',
#   'Research',
#   datetime.datetime(2024, 8, 18, 5, 10, 9)),
#  (100,
#   'Karen',
#   'Patterson',
#   'nrandolph@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.73'),
#   'SC',
#   1,
#   'Customer Service',
#   'Customer Service',
#   datetime.datetime(2024, 11, 11, 6, 59, 42)),
#  (101,
#   'Darrell',
#   'Collins',
#   'daniellescott@example.org',
#   'Data Science',
#   2028,
#   Decimal('2.72'),
#   'AZ',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 8, 27, 10, 40, 17)),
#  (102,
#   'Randy',
#   'Koch',
#   'clarktommy@example.net',
#   'Marketing',
#   2027,
#   Decimal('3.56'),
#   'KS',
#   0,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 9, 27, 18, 41, 46)),
#  (103,
#   'Amanda',
#   'Bruce',
#   'ginalopez@example.com',
#   'Finance',
#   2026,
#   Decimal('3.46'),
#   'ID',
#   1,
#   'Supply Chain',
#   'Research',
#   datetime.datetime(2024, 6, 11, 0, 19, 45)),
#  (104,
#   'Melissa',
#   'Castro',
#   'goldenalexis@example.com',
#   'Mechanical Engineering',
#   2027,
#   Decimal('3.44'),
#   'DC',
#   1,
#   'Data Analysis',
#   'Supply Chain',
#   datetime.datetime(2023, 12, 12, 3, 54, 57)),
#  (105,
#   'Susan',
#   'Chase',
#   'matthew34@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.59'),
#   'AS',
#   1,
#   'Finance',
#   'Software Development',
#   datetime.datetime(2024, 7, 14, 21, 4, 15)),
#  (106,
#   'William',
#   'Lambert',
#   'ycook@example.net',
#   'Business Administration',
#   2025,
#   Decimal('2.56'),
#   'IA',
#   0,
#   'Customer Service',
#   'Human Resources',
#   datetime.datetime(2024, 9, 9, 16, 20, 44)),
#  (107,
#   'Michael',
#   'Miller',
#   'kennethjohnson@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.15'),
#   'TX',
#   0,
#   'Customer Service',
#   'Research',
#   datetime.datetime(2025, 8, 25, 23, 1, 34)),
#  (108,
#   'Samantha',
#   'West',
#   'davisjennifer@example.net',
#   'Finance',
#   2028,
#   Decimal('3.60'),
#   'PA',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2024, 3, 10, 23, 58, 41)),
#  (109,
#   'Justin',
#   'West',
#   'ambermontes@example.org',
#   'Accounting',
#   2025,
#   Decimal('3.60'),
#   'GU',
#   1,
#   'Supply Chain',
#   'Supply Chain',
#   datetime.datetime(2024, 6, 6, 19, 55, 34)),
#  (110,
#   'Andrea',
#   'Hogan',
#   'michele35@example.com',
#   'Psychology',
#   2026,
#   Decimal('3.09'),
#   'ME',
#   1,
#   'Customer Service',
#   'Engineering',
#   datetime.datetime(2025, 10, 15, 19, 46, 53)),
#  (111,
#   'Christine',
#   'Austin',
#   'joediaz@example.com',
#   'Marketing',
#   2026,
#   Decimal('2.69'),
#   'MI',
#   0,
#   'Engineering',
#   'Data Analysis',
#   datetime.datetime(2025, 1, 6, 20, 43, 51)),
#  (112,
#   'Kathy',
#   'Campbell',
#   'melinda71@example.com',
#   'Computer Science',
#   2027,
#   Decimal('3.11'),
#   'GA',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 11, 13, 4, 18, 48)),
#  (113,
#   'Nicole',
#   'York',
#   'thomassmith@example.net',
#   'Data Science',
#   2024,
#   Decimal('3.81'),
#   'KY',
#   1,
#   'Research',
#   'Supply Chain',
#   datetime.datetime(2024, 5, 20, 9, 26, 48)),
#  (114,
#   'Anne',
#   'Baldwin',
#   'xmiller@example.net',
#   'Marketing',
#   2024,
#   Decimal('2.54'),
#   'RI',
#   0,
#   'Human Resources',
#   'Software Development',
#   datetime.datetime(2024, 1, 31, 5, 2, 33)),
#  (115,
#   'Aaron',
#   'Stark',
#   'brittanyflores@example.com',
#   'Computer Science',
#   2028,
#   Decimal('3.81'),
#   'VI',
#   1,
#   'Product Management',
#   'Software Development',
#   datetime.datetime(2025, 8, 4, 7, 10, 9)),
#  (116,
#   'Tammy',
#   'Mcgee',
#   'curtisramirez@example.com',
#   'Finance',
#   2025,
#   Decimal('3.27'),
#   'NM',
#   0,
#   'Software Development',
#   'Finance',
#   datetime.datetime(2024, 4, 2, 23, 30, 44)),
#  (117,
#   'Mary',
#   'Obrien',
#   'emilyshelton@example.com',
#   'Mechanical Engineering',
#   2025,
#   Decimal('3.57'),
#   'GA',
#   1,
#   'Data Analysis',
#   'Marketing',
#   datetime.datetime(2024, 5, 30, 15, 4, 29)),
#  (118,
#   'Joseph',
#   'Riggs',
#   'sara07@example.org',
#   'Economics',
#   2025,
#   Decimal('3.46'),
#   'CO',
#   0,
#   'Operations',
#   'Engineering',
#   datetime.datetime(2024, 3, 6, 1, 8, 11)),
#  (119,
#   'Parker',
#   'Warren',
#   'charles37@example.net',
#   'Economics',
#   2024,
#   Decimal('3.55'),
#   'NV',
#   1,
#   'Sales',
#   'Operations',
#   datetime.datetime(2025, 8, 8, 18, 3, 20)),
#  (120,
#   'Sonya',
#   'Lopez',
#   'adamsosa@example.org',
#   'Business Administration',
#   2026,
#   Decimal('2.83'),
#   'AS',
#   0,
#   'Product Management',
#   'Human Resources',
#   datetime.datetime(2024, 1, 26, 17, 13, 42)),
#  (121,
#   'Aaron',
#   'Roberson',
#   'anthonyjennings@example.com',
#   'Economics',
#   2027,
#   Decimal('3.98'),
#   'NM',
#   0,
#   'Data Analysis',
#   'Engineering',
#   datetime.datetime(2024, 12, 7, 12, 17, 55)),
#  (122,
#   'Tammy',
#   'Vaughn',
#   'danagray@example.com',
#   'Psychology',
#   2028,
#   Decimal('2.83'),
#   'OH',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2024, 6, 24, 5, 42, 47)),
#  (123,
#   'John',
#   'Forbes',
#   'trevinocindy@example.com',
#   'Biology',
#   2025,
#   Decimal('2.80'),
#   'DE',
#   1,
#   'Human Resources',
#   'Engineering',
#   datetime.datetime(2024, 5, 14, 7, 33, 49)),
#  (124,
#   'Brittany',
#   'Anderson',
#   'huntashley@example.org',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.56'),
#   'GA',
#   1,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 6, 16, 12, 29, 58)),
#  (125,
#   'Angela',
#   'Farmer',
#   'ryan06@example.org',
#   'Psychology',
#   2024,
#   Decimal('3.06'),
#   'NM',
#   1,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2024, 8, 13, 16, 30, 32)),
#  (126,
#   'Garrett',
#   'Pace',
#   'tnavarro@example.org',
#   'Economics',
#   2026,
#   Decimal('2.61'),
#   'KY',
#   1,
#   'Research',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 21, 17, 39, 15)),
#  (127,
#   'Brittany',
#   'Todd',
#   'smithjulia@example.com',
#   'Mechanical Engineering',
#   2028,
#   Decimal('3.04'),
#   'MT',
#   1,
#   'Engineering',
#   'Supply Chain',
#   datetime.datetime(2025, 7, 25, 4, 59, 24)),
#  (128,
#   'Jeffrey',
#   'Cantrell',
#   'mmarshall@example.com',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.80'),
#   'MA',
#   0,
#   'Customer Service',
#   'Software Development',
#   datetime.datetime(2024, 8, 16, 9, 11, 28)),
#  (129,
#   'Christine',
#   'Clay',
#   'ztaylor@example.org',
#   'Mechanical Engineering',
#   2024,
#   Decimal('3.01'),
#   'AL',
#   0,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 2, 11, 12, 29, 9)),
#  (130,
#   'Sandra',
#   'Sanchez',
#   'hedwards@example.net',
#   'Marketing',
#   2026,
#   Decimal('2.83'),
#   'KS',
#   0,
#   'Engineering',
#   'Engineering',
#   datetime.datetime(2025, 6, 1, 23, 53, 3)),
#  (131,
#   'Donna',
#   'Jackson',
#   'nicole47@example.net',
#   'Business Administration',
#   2028,
#   Decimal('3.91'),
#   'NC',
#   1,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2024, 12, 5, 15, 59, 35)),
#  (132,
#   'Michael',
#   'Wilson',
#   'chris61@example.org',
#   'Computer Science',
#   2024,
#   Decimal('3.42'),
#   'MO',
#   1,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 10, 11, 14, 27, 30)),
#  (133,
#   'Jason',
#   'Hanson',
#   'sherrycollins@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('2.66'),
#   'MO',
#   1,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2024, 3, 16, 20, 0, 37)),
#  (134,
#   'James',
#   'Moore',
#   'ryanquinn@example.org',
#   'Finance',
#   2025,
#   Decimal('2.68'),
#   'TN',
#   0,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2023, 12, 9, 16, 47, 31)),
#  (135,
#   'Robert',
#   'Poole',
#   'qhunter@example.org',
#   'Psychology',
#   2024,
#   Decimal('3.72'),
#   'CT',
#   0,
#   'Finance',
#   'Supply Chain',
#   datetime.datetime(2025, 6, 5, 15, 46, 38)),
#  (136,
#   'Jerry',
#   'Griffin',
#   'morgananthony@example.org',
#   'Finance',
#   2027,
#   Decimal('3.62'),
#   'SD',
#   0,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2025, 7, 14, 8, 2, 29)),
#  (137,
#   'Brent',
#   'Johnson',
#   'jefferyroberts@example.org',
#   'Mechanical Engineering',
#   2025,
#   Decimal('3.96'),
#   'WA',
#   1,
#   'Supply Chain',
#   'Software Development',
#   datetime.datetime(2025, 11, 4, 7, 44, 18)),
#  (138,
#   'Michele',
#   'Hines',
#   'garciakathy@example.net',
#   'Accounting',
#   2026,
#   Decimal('3.29'),
#   'VA',
#   1,
#   'Finance',
#   'Finance',
#   datetime.datetime(2024, 4, 28, 3, 56, 9)),
#  (139,
#   'Tara',
#   'Ruiz',
#   'zmeyer@example.net',
#   'Information Systems',
#   2025,
#   Decimal('3.42'),
#   'GU',
#   1,
#   'Supply Chain',
#   'Human Resources',
#   datetime.datetime(2025, 9, 12, 9, 46, 41)),
#  (140,
#   'Brian',
#   'Wallace',
#   'perezmichael@example.net',
#   'Computer Science',
#   2024,
#   Decimal('3.11'),
#   'NE',
#   1,
#   'Sales',
#   'Customer Service',
#   datetime.datetime(2024, 6, 22, 13, 37, 14)),
#  (141,
#   'Matthew',
#   'Ballard',
#   'cobbanthony@example.net',
#   'Business Administration',
#   2028,
#   Decimal('2.91'),
#   'MA',
#   1,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 8, 26, 22, 43, 15)),
#  (142,
#   'Elizabeth',
#   'Mcdonald',
#   'lorihoward@example.org',
#   'Psychology',
#   2026,
#   Decimal('2.55'),
#   'FL',
#   0,
#   'Software Development',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 20, 12, 12, 24)),
#  (143,
#   'Jodi',
#   'Goodman',
#   'amybrooks@example.net',
#   'Economics',
#   2026,
#   Decimal('3.47'),
#   'MO',
#   1,
#   'Marketing',
#   'Operations',
#   datetime.datetime(2025, 7, 24, 4, 28, 20)),
#  (144,
#   'Kelsey',
#   'Galloway',
#   'lanejohn@example.net',
#   'Finance',
#   2027,
#   Decimal('2.99'),
#   'GU',
#   0,
#   'Engineering',
#   'Product Management',
#   datetime.datetime(2024, 2, 21, 17, 10, 18)),
#  (145,
#   'Michelle',
#   'Powers',
#   'campbellandrea@example.org',
#   'Computer Science',
#   2027,
#   Decimal('2.67'),
#   'OR',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2024, 11, 9, 9, 25, 49)),
#  (146,
#   'Thomas',
#   'Barr',
#   'jgarcia@example.com',
#   'Information Systems',
#   2025,
#   Decimal('2.89'),
#   'OH',
#   1,
#   'Software Development',
#   'Human Resources',
#   datetime.datetime(2025, 3, 1, 15, 28, 54)),
#  (147,
#   'Hunter',
#   'Garza',
#   'gdiaz@example.com',
#   'Information Systems',
#   2024,
#   Decimal('2.81'),
#   'CO',
#   0,
#   'Research',
#   'Finance',
#   datetime.datetime(2025, 9, 22, 8, 47, 49)),
#  (148,
#   'Melissa',
#   'Jefferson',
#   'diana43@example.com',
#   'Electrical Engineering',
#   2028,
#   Decimal('3.08'),
#   'WA',
#   1,
#   'Supply Chain',
#   'Marketing',
#   datetime.datetime(2025, 4, 7, 18, 54, 38)),
#  (149,
#   'Richard',
#   'Williams',
#   'imendez@example.org',
#   'Data Science',
#   2026,
#   Decimal('2.79'),
#   'WV',
#   0,
#   'Engineering',
#   'Customer Service',
#   datetime.datetime(2025, 2, 3, 11, 15, 41)),
#  (150,
#   'Brandon',
#   'Fernandez',
#   'qtaylor@example.com',
#   'Psychology',
#   2024,
#   Decimal('3.81'),
#   'KS',
#   1,
#   'Research',
#   'Customer Service',
#   datetime.datetime(2024, 2, 11, 4, 52, 50)),
#  (151,
#   'James',
#   'Parrish',
#   'brianturner@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.94'),
#   'MD',
#   0,
#   'Operations',
#   'Marketing',
#   datetime.datetime(2024, 3, 15, 23, 18, 38)),
#  (152,
#   'Jessica',
#   'Mcclure',
#   'derek14@example.com',
#   'Marketing',
#   2026,
#   Decimal('3.81'),
#   'RI',
#   0,
#   'Engineering',
#   'Supply Chain',
#   datetime.datetime(2024, 8, 8, 18, 0, 32)),
#  (153,
#   'Stacey',
#   'Burgess',
#   'omoss@example.com',
#   'Information Systems',
#   2028,
#   Decimal('3.23'),
#   'WA',
#   0,
#   'Supply Chain',
#   'Sales',
#   datetime.datetime(2025, 4, 21, 2, 52, 45)),
#  (154,
#   'Carrie',
#   'Rivas',
#   'pruittbrian@example.org',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.79'),
#   'KY',
#   1,
#   'Sales',
#   'Finance',
#   datetime.datetime(2024, 4, 13, 4, 44, 24)),
#  (155,
#   'Jason',
#   'Petty',
#   'melanie57@example.org',
#   'Accounting',
#   2024,
#   Decimal('3.06'),
#   'SC',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 6, 3, 22, 13, 27)),
#  (156,
#   'Mark',
#   'Torres',
#   'amandarodriguez@example.com',
#   'Computer Science',
#   2024,
#   Decimal('3.10'),
#   'ME',
#   1,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2024, 6, 19, 7, 49, 19)),
#  (157,
#   'Linda',
#   'Lutz',
#   'dawn04@example.org',
#   'Business Administration',
#   2028,
#   Decimal('3.15'),
#   'AR',
#   1,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 5, 4, 7, 1, 22)),
#  (158,
#   'Allison',
#   'Harris',
#   'dianewilliamson@example.org',
#   'Psychology',
#   2025,
#   Decimal('3.69'),
#   'PR',
#   0,
#   'Sales',
#   'Research',
#   datetime.datetime(2024, 1, 6, 6, 35, 27)),
#  (159,
#   'Garrett',
#   'Levy',
#   'zachary40@example.com',
#   'Information Systems',
#   2026,
#   Decimal('3.70'),
#   'CT',
#   0,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2024, 11, 9, 15, 32, 14)),
#  (160,
#   'David',
#   'Willis',
#   'hstone@example.org',
#   'Marketing',
#   2028,
#   Decimal('3.69'),
#   'OR',
#   1,
#   'Sales',
#   'Customer Service',
#   datetime.datetime(2024, 2, 21, 6, 33, 40)),
#  (161,
#   'Kelly',
#   'Hawkins',
#   'theresafrancis@example.net',
#   'Mechanical Engineering',
#   2025,
#   Decimal('2.91'),
#   'VA',
#   0,
#   'Finance',
#   'Customer Service',
#   datetime.datetime(2025, 3, 29, 14, 18, 46)),
#  (162,
#   'Charles',
#   'Mayo',
#   'williamsdavid@example.net',
#   'Economics',
#   2026,
#   Decimal('3.77'),
#   'FL',
#   0,
#   'Data Analysis',
#   'Customer Service',
#   datetime.datetime(2025, 5, 19, 6, 41, 2)),
#  (163,
#   'Eric',
#   'Fletcher',
#   'samantha08@example.com',
#   'Business Administration',
#   2027,
#   Decimal('3.83'),
#   'IA',
#   0,
#   'Marketing',
#   'Customer Service',
#   datetime.datetime(2024, 2, 20, 5, 0, 43)),
#  (164,
#   'Kevin',
#   'Barber',
#   'ubaker@example.net',
#   'Computer Science',
#   2025,
#   Decimal('3.26'),
#   'PR',
#   1,
#   'Product Management',
#   'Human Resources',
#   datetime.datetime(2025, 11, 10, 16, 54, 23)),
#  (165,
#   'Megan',
#   'Yu',
#   'sarah37@example.com',
#   'Accounting',
#   2024,
#   Decimal('3.25'),
#   'FL',
#   0,
#   'Operations',
#   'Research',
#   datetime.datetime(2025, 8, 20, 12, 10, 51)),
#  (166,
#   'Heather',
#   'Olson',
#   'tiffany24@example.com',
#   'Economics',
#   2024,
#   Decimal('2.50'),
#   'FL',
#   1,
#   'Product Management',
#   'Operations',
#   datetime.datetime(2025, 8, 13, 21, 43, 28)),
#  (167,
#   'Frank',
#   'Martin',
#   'dukecody@example.net',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.68'),
#   'PW',
#   0,
#   'Software Development',
#   'Research',
#   datetime.datetime(2025, 4, 26, 16, 59, 35)),
#  (168,
#   'Megan',
#   'Peterson',
#   'crystalperez@example.net',
#   'Business Administration',
#   2025,
#   Decimal('2.65'),
#   'AR',
#   0,
#   'Operations',
#   'Customer Service',
#   datetime.datetime(2024, 9, 8, 10, 4, 43)),
#  (169,
#   'Kathleen',
#   'Andrews',
#   'heatherwood@example.com',
#   'Biology',
#   2025,
#   Decimal('3.75'),
#   'VT',
#   0,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2024, 9, 26, 1, 24, 53)),
#  (170,
#   'David',
#   'Obrien',
#   'xglover@example.org',
#   'Psychology',
#   2028,
#   Decimal('3.24'),
#   'LA',
#   1,
#   'Finance',
#   'Product Management',
#   datetime.datetime(2024, 9, 30, 16, 19, 44)),
#  (171,
#   'Brett',
#   'Stokes',
#   'tyler98@example.com',
#   'Information Systems',
#   2026,
#   Decimal('3.89'),
#   'GA',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 11, 21, 13, 9, 14)),
#  (172,
#   'Jennifer',
#   'Hood',
#   'lynchhaley@example.com',
#   'Data Science',
#   2024,
#   Decimal('3.07'),
#   'MA',
#   0,
#   'Operations',
#   'Data Analysis',
#   datetime.datetime(2024, 3, 30, 16, 33, 11)),
#  (173,
#   'Brett',
#   'Gardner',
#   'smithdavid@example.com',
#   'Marketing',
#   2027,
#   Decimal('3.89'),
#   'NH',
#   0,
#   'Sales',
#   'Sales',
#   datetime.datetime(2025, 8, 25, 10, 20, 21)),
#  (174,
#   'Jimmy',
#   'Warren',
#   'scottrobert@example.net',
#   'Business Administration',
#   2024,
#   Decimal('3.06'),
#   'TN',
#   0,
#   'Sales',
#   'Data Analysis',
#   datetime.datetime(2024, 5, 16, 2, 43, 13)),
#  (175,
#   'Rachel',
#   'Ortega',
#   'arobinson@example.org',
#   'Computer Science',
#   2028,
#   Decimal('3.76'),
#   'NY',
#   1,
#   'Software Development',
#   'Finance',
#   datetime.datetime(2024, 11, 23, 11, 2, 48)),
#  (176,
#   'Sheila',
#   'Mays',
#   'taylorcatherine@example.org',
#   'Information Systems',
#   2026,
#   Decimal('3.23'),
#   'SC',
#   0,
#   'Research',
#   'Customer Service',
#   datetime.datetime(2025, 7, 6, 17, 21, 49)),
#  (177,
#   'Jeanne',
#   'Newton',
#   'shellyhernandez@example.com',
#   'Economics',
#   2025,
#   Decimal('3.46'),
#   'PR',
#   0,
#   'Finance',
#   'Engineering',
#   datetime.datetime(2025, 8, 26, 6, 2, 14)),
#  (178,
#   'Robin',
#   'Thompson',
#   'randy22@example.com',
#   'Finance',
#   2025,
#   Decimal('3.15'),
#   'KY',
#   1,
#   'Supply Chain',
#   'Product Management',
#   datetime.datetime(2024, 1, 21, 4, 20)),
#  (179,
#   'Donna',
#   'Moore',
#   'michael20@example.com',
#   'Economics',
#   2026,
#   Decimal('2.68'),
#   'AR',
#   1,
#   'Product Management',
#   'Customer Service',
#   datetime.datetime(2025, 10, 11, 14, 41, 32)),
#  (180,
#   'George',
#   'Morton',
#   'contreraskelly@example.org',
#   'Business Administration',
#   2024,
#   Decimal('3.77'),
#   'TN',
#   1,
#   'Marketing',
#   'Research',
#   datetime.datetime(2025, 10, 27, 13, 9, 13)),
#  (181,
#   'Travis',
#   'Moore',
#   'daisyjohnson@example.com',
#   'Psychology',
#   2026,
#   Decimal('3.86'),
#   'CO',
#   0,
#   'Customer Service',
#   'Research',
#   datetime.datetime(2025, 10, 10, 17, 9, 3)),
#  (182,
#   'Brian',
#   'Roberson',
#   'hquinn@example.net',
#   'Computer Science',
#   2027,
#   Decimal('2.62'),
#   'MD',
#   0,
#   'Marketing',
#   'Product Management',
#   datetime.datetime(2025, 11, 8, 22, 31, 27)),
#  (183,
#   'Kelly',
#   'Hurst',
#   'amandabrady@example.com',
#   'Biology',
#   2028,
#   Decimal('3.57'),
#   'ID',
#   0,
#   'Product Management',
#   'Research',
#   datetime.datetime(2024, 8, 25, 1, 59, 35)),
#  (184,
#   'Erin',
#   'Richardson',
#   'keithharrison@example.net',
#   'Electrical Engineering',
#   2024,
#   Decimal('2.52'),
#   'AS',
#   0,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 2, 23, 22, 9, 10)),
#  (185,
#   'Colleen',
#   'Patterson',
#   'wburgess@example.com',
#   'Marketing',
#   2028,
#   Decimal('3.28'),
#   'MI',
#   0,
#   'Customer Service',
#   'Finance',
#   datetime.datetime(2024, 1, 17, 12, 59, 18)),
#  (186,
#   'William',
#   'Boyd',
#   'mrobles@example.net',
#   'Economics',
#   2026,
#   Decimal('2.99'),
#   'PW',
#   1,
#   'Customer Service',
#   'Marketing',
#   datetime.datetime(2025, 10, 30, 8, 35, 21)),
#  (187,
#   'Gregory',
#   'Weiss',
#   'sthomas@example.org',
#   'Psychology',
#   2025,
#   Decimal('3.91'),
#   'AZ',
#   1,
#   'Human Resources',
#   'Sales',
#   datetime.datetime(2025, 10, 12, 6, 18, 9)),
#  (188,
#   'Joseph',
#   'Wheeler',
#   'derrick19@example.net',
#   'Mechanical Engineering',
#   2027,
#   Decimal('2.97'),
#   'NE',
#   1,
#   'Engineering',
#   'Finance',
#   datetime.datetime(2025, 11, 3, 17, 12, 12)),
#  (189,
#   'Evan',
#   'Sanders',
#   'debra51@example.net',
#   'Accounting',
#   2026,
#   Decimal('2.75'),
#   'IA',
#   0,
#   'Human Resources',
#   'Finance',
#   datetime.datetime(2024, 8, 27, 0, 22, 12)),
#  (190,
#   'Alexandra',
#   'Mcdaniel',
#   'bakertracey@example.com',
#   'Biology',
#   2028,
#   Decimal('3.21'),
#   'HI',
#   0,
#   'Data Analysis',
#   'Data Analysis',
#   datetime.datetime(2025, 1, 14, 2, 1, 3)),
#  (191,
#   'Rachel',
#   'Smith',
#   'rbrady@example.org',
#   'Mechanical Engineering',
#   2024,
#   Decimal('2.68'),
#   'MH',
#   0,
#   'Supply Chain',
#   'Data Analysis',
#   datetime.datetime(2025, 11, 24, 4, 28, 36)),
#  (192,
#   'Cheryl',
#   'Parker',
#   'ahall@example.org',
#   'Computer Science',
#   2027,
#   Decimal('3.81'),
#   'MS',
#   0,
#   'Product Management',
#   'Engineering',
#   datetime.datetime(2024, 2, 4, 12, 10, 43)),
#  (193,
#   'John',
#   'Harris',
#   'jordan71@example.com',
#   'Business Administration',
#   2028,
#   Decimal('2.96'),
#   'FM',
#   0,
#   'Marketing',
#   'Sales',
#   datetime.datetime(2025, 5, 25, 19, 16, 36)),
#  (194,
#   'Howard',
#   'Brock',
#   'erodriguez@example.net',
#   'Business Administration',
#   2025,
#   Decimal('3.15'),
#   'SC',
#   1,
#   'Sales',
#   'Supply Chain',
#   datetime.datetime(2025, 2, 27, 9, 45, 47)),
#  (195,
#   'Ashley',
#   'Grimes',
#   'lstout@example.net',
#   'Computer Science',
#   2027,
#   Decimal('2.54'),
#   'SD',
#   0,
#   'Human Resources',
#   'Engineering',
#   datetime.datetime(2024, 10, 29, 5, 13, 58)),
#  (196,
#   'Darrell',
#   'Phillips',
#   'jsmith@example.com',
#   'Mechanical Engineering',
#   2026,
#   Decimal('3.68'),
#   'DE',
#   1,
#   'Research',
#   'Sales',
#   datetime.datetime(2024, 5, 15, 6, 3, 34)),
#  (197,
#   'Anthony',
#   'Powell',
#   'scottstevens@example.net',
#   'Marketing',
#   2027,
#   Decimal('2.95'),
#   'ID',
#   0,
#   'Data Analysis',
#   'Software Development',
#   datetime.datetime(2024, 11, 7, 15, 16, 31)),
#  (198,
#   'Tiffany',
#   'Tyler',
#   'glloyd@example.com',
#   'Business Administration',
#   2025,
#   Decimal('3.47'),
#   'MN',
#   1,
#   'Sales',
#   'Software Development',
#   datetime.datetime(2025, 5, 23, 22, 27, 10)),
#  (199,
#   'Michael',
#   'Taylor',
#   'sawyeranita@example.com',
#   'Marketing',
#   2025,
#   Decimal('2.71'),
#   'FM',
#   0,
#   'Software Development',
#   'Research',
#   datetime.datetime(2025, 8, 6, 19, 39, 8)),
#  (200,
#   'Pamela',
#   'White',
#   'joshua55@example.org',
#   'Business Administration',
#   2024,
#   Decimal('2.66'),
#   'CT',
#   1,
#   'Product Management',
#   'Customer Service',
#   datetime.datetime(2024, 6, 11, 16, 0, 19))]

# %% [markdown]
# Use Case 1

# %%
sql_file = "../schema/use_case_1.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#    position_id         title location required_experience work_mode  \
# 0          111  Chiropractor       MA             2 years    Hybrid
#
#           company_name job_category
# 0  Harris, Bell and Yu    Marketing
# Use Case executed

# %% [markdown]
# Use Case 2

# %%
sql_file = "../schema/use_case_2.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#     position_id                                  title location  \
# 0            63  Senior tax professional/tax inspector       ID
# 1           151            Industrial/product designer       VA
# 2           198                    Scientist, forensic       RI
# 3            91               Surveyor, land/geomatics       IN
# 4           152                    Trade mark attorney       VT
# 5            25        Producer, television/film/video       RI
# 6           187                          Haematologist       GA
# 7            27                             Counsellor       AL
# 8            38                         Science writer       VI
# 9           163           Administrator, Civil Service       WA
# 10          182  Medical laboratory scientific officer       UT
#
#    required_experience                  company_name required_major
# 0              0 years                Moran and Sons     Accounting
# 1              4 years                    Malone Ltd     Accounting
# 2              5 years       Duarte, Brown and Stout     Accounting
# 3              3 years                  Rivera-Perry     Accounting
# 4              2 years              Johnson and Sons     Accounting
# 5              4 years              Wilkerson-Harper     Accounting
# 6              0 years       Crane, Cain and Edwards     Accounting
# 7              0 years    Walls, Murphy and Garrison     Accounting
# 8              3 years                  Greene-Jones     Accounting
# 9              1 years                     Burke Ltd     Accounting
# 10             4 years  Reynolds, Crawford and Lopez     Accounting
# Use Case executed

# %% [markdown]
# Use Case 3

# %%
sql_file = "../schema/use_case_3.sql"

cur.execute("DROP PROCEDURE IF EXISTS Apply_For_Position")

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

try: cur.execute("CALL Apply_For_Position(4, 198)")
except Exception as e: print(e)

cur.execute("CALL Apply_For_Position(3, 198)")
cur.execute("SELECT * FROM Application ORDER BY application_id DESC LIMIT 1")

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)

db.commit()
print("Use Case executed")
# Out:
# SQL file loaded
# 1644 (HY000): This position required major is Accounting
#    application_id  user_id  position_id application_date     status notes
# 0             690        3          198       2025-12-01  Submitted  None
# Use Case executed

# %% [markdown]
# Use Case 4

# %%
sql_file = "../schema/use_case_4.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#    num_applications
# 0                14
# Use Case executed

# %% [markdown]
# Use Case 5

# %%
sql_file = "../schema/use_case_5.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#      gpa   first_name  last_name
# 0   3.96        Brent    Johnson
# 1   3.93        Tracy    Kennedy
# 2   3.86      Shannon       Wall
# 3   3.84  Christopher     Miller
# 4   3.81      Jessica    Mcclure
# 5   3.60     Samantha       West
# 6   3.44      Melissa     Castro
# 7   3.43         Lisa    Wheeler
# 8   3.33      Shannon      Mayer
# 9   3.32       Rhonda     Miller
# 10  3.25        Megan         Yu
# 11  2.75       Nicole       Shaw
# 12  2.75         Evan    Sanders
# 13  2.73        Karen  Patterson
# Use Case executed

# %% [markdown]
# Use Case 6

# %%
sql_file = "../schema/use_case_6.sql"

cur.execute("DROP TRIGGER IF EXISTS Notify_Matching_Majors;")

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)
    
print("Use Case executed")
# Out:
# SQL file loaded
# Use Case executed

# %% [markdown]
# Testing the trigger

# %%
sql_file = "../schema/use_case_6_test.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

position_id = cur.lastrowid

cur.execute("""
    SELECT u.first_name, u.last_name, u.major, a.notes
    FROM Application a
    JOIN Users u ON a.user_id = u.user_id
    WHERE a.position_id = %s
""", (position_id,))

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
# Out:
# SQL file loaded
#    first_name  last_name    major  \
# 0        Erik      Smith  Biology
# 1     Maureen    Roberts  Biology
# 2     Tiffany   Hamilton  Biology
# 3      Meagan      Lewis  Biology
# 4      Rhonda     Miller  Biology
# 5      Daniel   Phillips  Biology
# 6        Greg   Robinson  Biology
# 7        Tony     Jacobs  Biology
# 8      Hannah       Horn  Biology
# 9   Christina  Velazquez  Biology
# 10      Larry      Ramos  Biology
# 11       John     Forbes  Biology
# 12   Kathleen    Andrews  Biology
# 13      Kelly      Hurst  Biology
# 14  Alexandra   Mcdaniel  Biology
#
#                                                 notes
# 0   Erik! A new position is available: Biology Res...
# 1   Maureen! A new position is available: Biology ...
# 2   Tiffany! A new position is available: Biology ...
# 3   Meagan! A new position is available: Biology R...
# 4   Rhonda! A new position is available: Biology R...
# 5   Daniel! A new position is available: Biology R...
# 6   Greg! A new position is available: Biology Res...
# 7   Tony! A new position is available: Biology Res...
# 8   Hannah! A new position is available: Biology R...
# 9   Christina! A new position is available: Biolog...
# 10  Larry! A new position is available: Biology Re...
# 11  John! A new position is available: Biology Res...
# 12  Kathleen! A new position is available: Biology...
# 13  Kelly! A new position is available: Biology Re...
# 14  Alexandra! A new position is available: Biolog...

# %% [markdown]
# Use Case 7

# %%
sql_file = "../schema/use_case_7.sql"

with open(sql_file, "r") as f:
    sql_script = f.read()
print("SQL file loaded")

cur.execute(sql_script)

df = pd.DataFrame(cur.fetchall(), columns=[desc[0] for desc in cur.description])
display(df)
    
print("Use Case executed")
# Out:
# SQL file loaded
#    position_id                                  title location work_mode  \
# 0           63  Senior tax professional/tax inspector       ID   On-site
# 1           91               Surveyor, land/geomatics       IN   On-site
# 2          152                    Trade mark attorney       VT   On-site
#
#      term    job_type required_major
# 0    Fall  Internship     Accounting
# 1  Summer  Internship     Accounting
# 2  Spring  Internship     Accounting
# Use Case executed

# %% [markdown]
# Close cursor and database

# %%
cur.close()
db.close()
print("All Use Cases executed successfully.")
# Out:
# All Use Cases executed successfully.
